# %% [markdown]
# # Modeling Train  Tracking Registering the models

# %%
import pandas as pd
import mlflow
import mlflow.sklearn
from sklearn.feature_extraction import DictVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib
import os

# %%
import pandas as pd
from typing import List, Tuple

def load_and_combine_months(file_paths: List[str]) -> pd.DataFrame:
    """
    Load multiple monthly parquet files and combine them into one DataFrame.
    Adds a 'month' column for time-based splitting.
    """
    dfs = []
    
    for path in file_paths:
        print(f"Loading: {path}")
        df = pd.read_parquet(path)
        
        # استخراج ماه از نام فایل (فرض: نام فایل شامل تاریخ است)
        # مثال: yellow_tripdata_2026-01.parquet → month = 1
        month = int(path.split('-')[-1].split('.')[0].split('_')[0])

        df['month'] = month
        
        dfs.append(df)
    
    combined = pd.concat(dfs, ignore_index=True)
    print(f"Total combined data shape: {combined.shape}")
    return combined


def split_train_validation_by_month(
    df: pd.DataFrame, 
    train_months: List[int], 
    val_month: int
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Split data into Train and Validation based on month.
    """
    train_df = df[df['month'].isin(train_months)].copy()
    val_df = df[df['month'] == val_month].copy()
    
    print(f"Train shape: {train_df.shape} | Months: {train_months}")
    print(f"Validation shape: {val_df.shape} | Month: {val_month}")
    
    return train_df, val_df

# %%
# مسیر فایل‌ها
file_paths = [
    "/Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-01_processed.parquet",
    "/Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-02_processed.parquet",
    "/Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-03_processed.parquet",
]

# بارگذاری و ترکیب
df = load_and_combine_months(file_paths)

# تقسیم زمانی
train, val = split_train_validation_by_month(
    df=df,
    train_months=[1, 2],   # ماه ۱ و ۲ برای Train
    val_month=3            # ماه ۳ برای Validation
)
# Out:
# Loading: /Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-01_processed.parquet
# Loading: /Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-02_processed.parquet
# Loading: /Users/mohsen/Desktop/nyc_duration_prediction/data/processed/yellow_tripdata_2026-03_processed.parquet
# Total combined data shape: (7748178, 28)
# Train shape: (4838269, 28) | Months: [1, 2]
# Validation shape: (2909909, 28) | Month: 3

# %%
train_df = train.sample(n=5000, random_state = 42).reset_index(drop=True)
val_df = val.sample(n=500, random_state = 42).reset_index(drop=True)

# %%
def select_features(df: pd.DataFrame):
    """Select features and define categorical vs numerical."""
    categorical = ['hour_category','PU_DO']           # فقط این را وکتورایز می‌کنیم (تعداد دسته کم است)
    
    numerical = [
        'trip_distance',
        'PULocationID',
        'DOLocationID',
        'pickup_dayofweek',
        'pickup_hour',
        'is_rush_hour',
        'is_weekend'
    ]
    target = 'duration'

    
    df = df[categorical + numerical + [target]].copy()
    return df, categorical, numerical, target


def vectorize_features(train_df, val_df, categorical, numerical):
    """Convert features using DictVectorizer."""
    print("Vectorizing features...")

    dv = DictVectorizer()

    train_dicts = train_df[categorical + numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)

    val_dicts = val_df[categorical + numerical].to_dict(orient='records')
    X_val = dv.transform(val_dicts)

    return X_train, X_val, dv

# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
print("Tracking URI:", mlflow.get_tracking_uri())
mlflow.set_experiment('nyc_duration_prediction')
# Out:
# Tracking URI: http://127.0.0.1:5000
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1785237891492, effective_trace_archival_retention=None, experiment_id='1', last_update_time=1785237891492, lifecycle_stage='active', name='nyc_duration_prediction', tags={}, trace_location=None, workspace='default'>

# %%
import mlflow
import mlflow.sklearn
import joblib
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.feature_extraction import DictVectorizer
from pathlib import Path

with mlflow.start_run(run_name="rf_target_encoding_v7"):

    # ========================
    # انتخاب فیچرها
    # ========================
    train_df, categorical, numerical, target = select_features(train_df)
    val_df, _, _, _ = select_features(val_df)

    # ========================
    # Target Encoding برای PU_DO (حرفه‌ای)
    # ========================
    target_encoder = TargetEncoder(
        cols=['PU_DO'], 
        smoothing=15, 
        min_samples_leaf=30
    )
    
    # فقط روی داده Train فیت می‌کنیم
    target_encoder.fit(train_df[['PU_DO']], train_df[target])
    
    train_df['PU_DO_encoded'] = target_encoder.transform(train_df[['PU_DO']])
    val_df['PU_DO_encoded'] = target_encoder.transform(val_df[['PU_DO']])

    # ========================
    # فیچرهای نهایی برای مدل
    # ========================
    # PU_DO را حذف می‌کنیم و نسخه encode شده‌اش را نگه می‌داریم
    final_categorical = ['hour_category']                    # فقط این را وان‌هات می‌کنیم
    final_numerical = ['trip_distance', 'pickup_dayofweek', 'PU_DO_encoded']

    # ========================
    # وکتورایز کردن (فقط hour_category)
    # ========================
    dv = DictVectorizer()
    
    train_dicts = train_df[final_categorical + final_numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)

    val_dicts = val_df[final_categorical + final_numerical].to_dict(orient='records')
    X_val = dv.transform(val_dicts)

    y_train = train_df[target].values
    y_val = val_df[target].values

    print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}")

    # ========================
    # آموزش مدل
    # ========================
    print("MODEL STARTING")
    model = RandomForestRegressor(
        n_estimators=50,
        max_depth=15,
        min_samples_leaf=5,
        random_state=42,
        n_jobs=-1
    )
    model.fit(X_train, y_train)

    # پیش‌بینی
    y_pred = model.predict(X_val)

    # ========================
    # محاسبه متریک‌ها
    # ========================
    mae = mean_absolute_error(y_val, y_pred)
    rmse = mean_squared_error(y_val, y_pred)   # اصلاح شده
    r2 = r2_score(y_val, y_pred)

    print(f"MAE: {mae:.3f}, RMSE: {rmse:.3f}, R2: {r2:.4f}")

    # ========================
    # لاگ کردن در MLflow
    # ========================
    mlflow.log_params({
        "model_type": "RandomForest",
        "n_estimators": 150,
        "max_depth": 15,
        "min_samples_leaf": 5,
        "target_encoding": "PU_DO",
        "smoothing": 15,
        "min_samples_leaf_target": 30,
        "final_categorical": str(final_categorical),
        "final_numerical": str(final_numerical)
    })

    mlflow.log_metrics({
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    })
    model_name = "NYC_DURATION_PREDOCTION"
    # ========================
    # ذخیره مدل و Encoderها
    # ========================
    model_info = mlflow.sklearn.log_model(
            sk_model=model,
            artifact_path="model",
            registered_model_name=model_name,
            metadata={
                "training_data_months": "Jan-Feb 2026",
                "features": ["trip_distance", "PU_DO_encoded", "hour_category"],
                "target_encoding": True
            }
        )
    
    client = MlflowClient()
    client.update_model_version(
            name=model_name,
            version=model_info.registered_model_version,
            description="Trained with Target Encoding on PU_DO. Best model so far.1234567"
        )


    client.set_model_version_tag(
            name=model_name,
            version=model_info.registered_model_version,
            key="validation_rmse",
            value=str(round(rmse, 3))
        )

    # ذخیره TargetEncoder
    joblib.dump(target_encoder, "target_encoder.pkl")
    mlflow.log_artifact("target_encoder.pkl", artifact_path="preprocessing")

    # ذخیره DictVectorizer
    joblib.dump(dv, "dict_vectorizer.pkl")
    mlflow.log_artifact("dict_vectorizer.pkl", artifact_path="preprocessing")

    print("Run completed and logged to MLflow.")
# Out:
# 2026/07/29 16:28:08 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Train shape: (2000, 8), Validation shape: (500, 8)
# MODEL STARTING
# MAE: 1.931, RMSE: 13.211, R2: 0.9430
# 2026/07/29 16:28:12 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'NYC_DURATION_PREDOCTION' already exists. Creating a new version of this model...
# 2026/07/29 16:28:12 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: NYC_DURATION_PREDOCTION, version 6
# Created version '6' of model 'NYC_DURATION_PREDOCTION'.
# Run completed and logged to MLflow.
# 🏃 View run rf_target_encoding_v7 at: http://127.0.0.1:5000/#/experiments/1/runs/1c1ad0f7b9364cd3b0e087e27c1cd171
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
from mlflow.tracking import MlflowClient
client = MlflowClient("http://127.0.0.1:5000")

# %%
client.update_model_version(
            name="NYC_DURATION_PREDOCTION",
            version=model_info.registered_model_version,
            description="Trained with Target Encoding on PU_DO. Best model so far."
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 client.update_model_version(
#       2             name="NYC_DURATION_PREDOCTION",
# ----> 3             version=model_info.registered_model_version,
#       4             description="Trained with Target Encoding on PU_DO. Best model so far."
#       5         )
#
# NameError: name 'model_info' is not defined

# %% [markdown]
# client.search_registered_models()
# mlflow.search_experiments()
# client.search_runs(experiment_ids='1')[0].info.run_id
# run_id = client.search_runs(experiment_ids='1')[0].info.run_id
# mlflow.register_model(
#     model_uri=f"runs:/{run_id}/model",
#     name='NYC_Duration_Model'
# )

# %% [markdown]
# # run the xgboost models with optuma

# %%
import mlflow 
mlflow.set_tracking_uri("http://127.0.0.1:5000")
print("Tracking URI:", mlflow.get_tracking_uri())
mlflow.set_experiment('nyc_duration_prediction_boosting_model')
# Out:
# Tracking URI: http://127.0.0.1:5000
# 2026/08/02 12:55:49 INFO mlflow.tracking.fluent: Experiment with name 'nyc_duration_prediction_boosting_model' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/2', creation_time=1785662749491, effective_trace_archival_retention=None, experiment_id='2', last_update_time=1785662749491, lifecycle_stage='active', name='nyc_duration_prediction_boosting_model', tags={}, trace_location=None, workspace='default'>

# %%
def select_features(df: pd.DataFrame):
    """Select features and define categorical vs numerical."""
    categorical = ['hour_category','PU_DO']           # فقط این را وکتورایز می‌کنیم (تعداد دسته کم است)
    
    numerical = [
        'trip_distance',
        'PULocationID',
        'DOLocationID',
        'pickup_dayofweek',
        'pickup_hour',
        'is_rush_hour',
        'is_weekend'
    ]
    target = 'duration'

    
    df = df[categorical + numerical + [target]].copy()
    return df, categorical, numerical, target


def vectorize_features(train_df, val_df, categorical, numerical):
    """Convert features using DictVectorizer."""
    print("Vectorizing features...")

    dv = DictVectorizer()

    train_dicts = train_df[categorical + numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)

    val_dicts = val_df[categorical + numerical].to_dict(orient='records')
    X_val = dv.transform(val_dicts)

    return X_train, X_val, dv

# %%
import mlflow
import mlflow.sklearn
import joblib
from category_encoders import TargetEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.feature_extraction import DictVectorizer
from pathlib import Path

# ========================
# انتخاب فیچرها
# ========================
train_df, categorical, numerical, target = select_features(train_df)
val_df, _, _, _ = select_features(val_df)

# ========================
# Target Encoding برای PU_DO (حرفه‌ای)
# ========================
target_encoder = TargetEncoder(
    cols=['PU_DO'], 
    smoothing=15, 
    min_samples_leaf=30
)

# ========================
# وکتورایز کردن (فقط hour_category)
# ========================
dv= DictVectorizer()

train_dicts = train_df[categorical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = val_df[categorical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

y_train = train_df[target].values
y_val = val_df[target].values

print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}")
print(y_train[0:20])
# Out:
# Train shape: (5000, 5), Validation shape: (500, 5)
# [12.27 25.48  3.78 13.1  17.55 25.53 49.87 17.   12.45 13.25  6.72 17.15
#  26.6  37.83 32.55 15.73 40.07 19.43 16.03 12.57]

# %%
import mlflow
import optuna
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from mlflow.models import infer_signature


# ========================
# تابع هدف (Objective)
# ========================
def objective(trial, X_train, X_val, y_train, y_val):
    with mlflow.start_run(nested=True, run_name=f"lgb_trial_{trial.number}"):

        params = {
            'objective': 'regression',
            'metric': 'rmse',
            'n_estimators': trial.suggest_int('n_estimators', 300, 2000),
            'num_leaves': trial.suggest_int('num_leaves', 20, 150),
            'max_depth': trial.suggest_int('max_depth', 3, 12),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
            'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
            'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
            'random_state': 42,
            'n_jobs': 2,
            'verbose': -1
        }

        model = lgb.LGBMRegressor(**params)

        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
        )

        y_pred = model.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)

        mlflow.log_params(params)
        mlflow.log_metric("rmse", rmse)

        return rmse


# ========================
# تابع اصلی Tuning (بدون ثبت مدل)
# ========================
def run_lightgbm_optuna_tuning(X_train, X_val, y_train, y_val, n_trials=50):
    
    with mlflow.start_run(run_name="lightgbm_optuna_tuning_version_4"):
        
        study = optuna.create_study(
            direction="minimize",
            study_name="LightGBM_Hyperparameter_Tuning",
            pruner=optuna.pruners.MedianPruner()
        )

        study.optimize(
            lambda trial: objective(trial, X_train, X_val, y_train, y_val),
            n_trials=n_trials,
            show_progress_bar=True
        )

        print("\n" + "="*60)
        print(f"بهترین RMSE: {study.best_value:.4f}")
        for k, v in study.best_params.items():
            print(f"  {k}: {v}")
        print("="*60)

        mlflow.log_params(study.best_params)
        mlflow.log_metric("best_rmse", study.best_value)

        # ========================
        # آموزش مدل نهایی (فقط لاگ می‌شود، ثبت نمی‌شود)
        # ========================
        best_params = study.best_params.copy()
        best_params.update({
            'objective': 'regression',
            'metric': 'rmse',
            'random_state': 42,
            'n_jobs': 2,
            'verbose': -1
        })

        final_model = lgb.LGBMRegressor(**best_params)

        final_model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
        )

        # ارزیابی نهایی
        y_pred = final_model.predict(X_val)
        final_rmse = root_mean_squared_error(y_val, y_pred)
        final_mae = mean_absolute_error(y_val, y_pred)
        final_r2 = r2_score(y_val, y_pred)

        mlflow.log_metrics({
            "final_rmse": final_rmse,
            "final_mae": final_mae,
            "final_r2": final_r2
        })

        # ========================
        # فقط مدل را لاگ می‌کنیم (ثبت در Registry نمی‌کنیم)
        # ========================
        signature = infer_signature(X_train, y_train)
        mlflow.sklearn.log_model(
            sk_model=final_model,
            artifact_path="model",
            signature=signature,                    
            skops_trusted_types=[
                "lightgbm.sklearn.LGBMRegressor",
                "lightgbm.basic.Booster",
                "collections.OrderedDict"
            ],
            metadata={
                "description": "this run use without auto registery model",
                "training_period": "AUG 2026",
                "feature_engineering": "PU_OP => target endcoding",
                "number_of_trials": 50,
                "best_rmse": round(final_rmse, 4),
            }
        )

        print("\nمدل نهایی آموزش دیده و لاگ شد (هنوز در Registry ثبت نشده).")
        return final_model, study

# ========================
# اجرا
# ========================
if __name__ == "__main__":
    run_lightgbm_optuna_tuning(X_train, X_val, y_train, y_val, n_trials=50)
# Out:
# [I 2026-08-02 13:30:02,956] A new study created in memory with name: LightGBM_Hyperparameter_Tuning
#   0%|                                                                                                         | 0/50 [00:00<?, ?it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.0982:   2%|█▏                                                           | 1/50 [00:00<00:05,  8.23it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.0982:   2%|█▏                                                           | 1/50 [00:00<00:05,  8.23it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.0982:   6%|███▋                                                         | 3/50 [00:00<00:04, 11.00it/s]
# 🏃 View run lgb_trial_0 at: http://127.0.0.1:5000/#/experiments/2/runs/9b26e9f8cdf94c6f8ba497457cc4e45c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,079] Trial 0 finished with value: 15.09819580100194 and parameters: {'n_estimators': 445, 'num_leaves': 83, 'max_depth': 9, 'learning_rate': 0.014579855011358705, 'feature_fraction': 0.6142362795318519, 'bagging_fraction': 0.8442154451294264, 'bagging_freq': 7, 'min_child_samples': 95, 'reg_alpha': 0.02144026543318115, 'reg_lambda': 2.8950447209056405e-08}. Best is trial 0 with value: 15.09819580100194.
# 🏃 View run lgb_trial_1 at: http://127.0.0.1:5000/#/experiments/2/runs/1fdc602dcebd49838a6738591ed7543e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,169] Trial 1 finished with value: 15.101785375377544 and parameters: {'n_estimators': 714, 'num_leaves': 73, 'max_depth': 9, 'learning_rate': 0.18202293581333542, 'feature_fraction': 0.754536482684639, 'bagging_fraction': 0.930261847798972, 'bagging_freq': 5, 'min_child_samples': 85, 'reg_alpha': 1.347152646484276e-06, 'reg_lambda': 1.848560350863379e-05}. Best is trial 0 with value: 15.09819580100194.
# 🏃 View run lgb_trial_2 at: http://127.0.0.1:5000/#/experiments/2/runs/5270df4fa66a4088b1b3b9bbd456a7da
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,239] Trial 2 finished with value: 15.100629577787313 and parameters: {'n_estimators': 1842, 'num_leaves': 140, 'max_depth': 12, 'learning_rate': 0.1863661281747376, 'feature_fraction': 0.7057214244057396, 'bagging_fraction': 0.7876114885334211, 'bagging_freq': 9, 'min_child_samples': 14, 'reg_alpha': 0.0549246137916125, 'reg_lambda': 1.068656156237577}. Best is trial 0 with value: 15.09819580100194.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.0982:   6%|███▋                                                         | 3/50 [00:00<00:04, 11.00it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 4. Best value: 15.0951:  10%|██████                                                       | 5/50 [00:00<00:03, 11.96it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  10%|██████▏                                                       | 5/50 [00:00<00:03, 11.96it/s]
# 🏃 View run lgb_trial_3 at: http://127.0.0.1:5000/#/experiments/2/runs/a8757d37a620428abc8ab6ebe1255f9c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,334] Trial 3 finished with value: 15.09849501773972 and parameters: {'n_estimators': 1067, 'num_leaves': 112, 'max_depth': 8, 'learning_rate': 0.024405524278747634, 'feature_fraction': 0.8847518650005346, 'bagging_fraction': 0.7844960291641175, 'bagging_freq': 4, 'min_child_samples': 33, 'reg_alpha': 0.0510615932291022, 'reg_lambda': 2.8338905226863105e-07}. Best is trial 0 with value: 15.09819580100194.
# 🏃 View run lgb_trial_4 at: http://127.0.0.1:5000/#/experiments/2/runs/38fb22b9f9a642f490ebbee8b90b910b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,393] Trial 4 finished with value: 15.095117377336727 and parameters: {'n_estimators': 588, 'num_leaves': 63, 'max_depth': 9, 'learning_rate': 0.25322304169312654, 'feature_fraction': 0.619579768368743, 'bagging_fraction': 0.6214123757689862, 'bagging_freq': 8, 'min_child_samples': 91, 'reg_alpha': 1.2668266038234308e-08, 'reg_lambda': 0.001145860093637994}. Best is trial 4 with value: 15.095117377336727.
# 🏃 View run lgb_trial_5 at: http://127.0.0.1:5000/#/experiments/2/runs/87e2e4978d8c495681f37ec746d36841
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,478] Trial 5 finished with value: 15.095006677169335 and parameters: {'n_estimators': 1772, 'num_leaves': 130, 'max_depth': 11, 'learning_rate': 0.07537060687848732, 'feature_fraction': 0.6908307812968808, 'bagging_fraction': 0.6007800029401524, 'bagging_freq': 5, 'min_child_samples': 41, 'reg_alpha': 0.08935070835248186, 'reg_lambda': 1.5452416629532908e-07}. Best is trial 5 with value: 15.095006677169335.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  14%|████████▋                                                     | 7/50 [00:00<00:03, 12.40it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  14%|████████▋                                                     | 7/50 [00:00<00:03, 12.40it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  18%|███████████▏                                                  | 9/50 [00:00<00:03, 12.60it/s]
# 🏃 View run lgb_trial_6 at: http://127.0.0.1:5000/#/experiments/2/runs/a678b82cfad147f28edc85cf7ed1efdb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,546] Trial 6 finished with value: 15.098920442278915 and parameters: {'n_estimators': 1964, 'num_leaves': 139, 'max_depth': 9, 'learning_rate': 0.06074064058342406, 'feature_fraction': 0.6468595164295389, 'bagging_fraction': 0.821158328114127, 'bagging_freq': 2, 'min_child_samples': 39, 'reg_alpha': 1.4951954216961038e-05, 'reg_lambda': 1.7915747445026534e-05}. Best is trial 5 with value: 15.095006677169335.
# 🏃 View run lgb_trial_7 at: http://127.0.0.1:5000/#/experiments/2/runs/35d201417d7f4aac8ef3b41ab8b8f58c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,630] Trial 7 finished with value: 15.0974978361515 and parameters: {'n_estimators': 572, 'num_leaves': 32, 'max_depth': 10, 'learning_rate': 0.033918279901830405, 'feature_fraction': 0.9083370086354217, 'bagging_fraction': 0.734912973128632, 'bagging_freq': 8, 'min_child_samples': 100, 'reg_alpha': 1.4072209027937248e-06, 'reg_lambda': 0.11504891401041484}. Best is trial 5 with value: 15.095006677169335.
# 🏃 View run lgb_trial_8 at: http://127.0.0.1:5000/#/experiments/2/runs/62da5a7b2b5942be997e809762fe4813
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,700] Trial 8 finished with value: 15.100802446472025 and parameters: {'n_estimators': 490, 'num_leaves': 56, 'max_depth': 12, 'learning_rate': 0.03361412943484797, 'feature_fraction': 0.8434822606673276, 'bagging_fraction': 0.9148790132045118, 'bagging_freq': 8, 'min_child_samples': 83, 'reg_alpha': 0.004632186819740377, 'reg_lambda': 2.3997632934240793e-05}. Best is trial 5 with value: 15.095006677169335.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  18%|███████████▏                                                  | 9/50 [00:00<00:03, 12.60it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 5. Best value: 15.095:  22%|█████████████▍                                               | 11/50 [00:00<00:02, 13.65it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  22%|████████████▉                                              | 11/50 [00:00<00:02, 13.65it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_9 at: http://127.0.0.1:5000/#/experiments/2/runs/964e8397a8b5448b9f0c92bd8faa3f2d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,765] Trial 9 finished with value: 15.09894345482639 and parameters: {'n_estimators': 528, 'num_leaves': 40, 'max_depth': 3, 'learning_rate': 0.08661876748487156, 'feature_fraction': 0.8545865210644641, 'bagging_fraction': 0.8741353309160822, 'bagging_freq': 2, 'min_child_samples': 37, 'reg_alpha': 0.004141180114871436, 'reg_lambda': 0.021929515693384777}. Best is trial 5 with value: 15.095006677169335.
# 🏃 View run lgb_trial_10 at: http://127.0.0.1:5000/#/experiments/2/runs/1cf57ad4660649a48f17ef5a20894c08
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,824] Trial 10 finished with value: 15.100106537149975 and parameters: {'n_estimators': 1445, 'num_leaves': 103, 'max_depth': 5, 'learning_rate': 0.09167196492972801, 'feature_fraction': 0.9707585159163281, 'bagging_fraction': 0.9880420912354236, 'bagging_freq': 5, 'min_child_samples': 62, 'reg_alpha': 0.8630625801660312, 'reg_lambda': 6.8702358197293245}. Best is trial 5 with value: 15.095006677169335.
# 🏃 View run lgb_trial_11 at: http://127.0.0.1:5000/#/experiments/2/runs/e2fb7d6c123f48f68fa03d32394edf99
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,893] Trial 11 finished with value: 15.089926682176632 and parameters: {'n_estimators': 1145, 'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.2898227360218166, 'feature_fraction': 0.7137864090921783, 'bagging_fraction': 0.6188516968851362, 'bagging_freq': 10, 'min_child_samples': 61, 'reg_alpha': 2.7141983430947504e-08, 'reg_lambda': 0.0016130729621419192}. Best is trial 11 with value: 15.089926682176632.
# Best trial: 11. Best value: 15.0899:  26%|███████████████▎                                           | 13/50 [00:01<00:02, 13.75it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  26%|███████████████▎                                           | 13/50 [00:01<00:02, 13.75it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  30%|█████████████████▋                                         | 15/50 [00:01<00:02, 14.30it/s]
# 🏃 View run lgb_trial_12 at: http://127.0.0.1:5000/#/experiments/2/runs/7ebdaf12b4ce4797931eea0c7c07d2bf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:03,967] Trial 12 finished with value: 15.090628178255319 and parameters: {'n_estimators': 1441, 'num_leaves': 119, 'max_depth': 6, 'learning_rate': 0.11884080564701056, 'feature_fraction': 0.7558567672019431, 'bagging_fraction': 0.6050339564813377, 'bagging_freq': 10, 'min_child_samples': 62, 'reg_alpha': 8.998351564945763, 'reg_lambda': 0.001158437032556083}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_13 at: http://127.0.0.1:5000/#/experiments/2/runs/a48b4126aa8246fdbd5a32beccabe0b7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,029] Trial 13 finished with value: 15.094335201350265 and parameters: {'n_estimators': 1180, 'num_leaves': 104, 'max_depth': 6, 'learning_rate': 0.2981822709803603, 'feature_fraction': 0.7739875088068207, 'bagging_fraction': 0.6751531738838344, 'bagging_freq': 10, 'min_child_samples': 67, 'reg_alpha': 5.333415369460542, 'reg_lambda': 0.0013183535385140732}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_14 at: http://127.0.0.1:5000/#/experiments/2/runs/a8697075c90d496f80d4898ae8f381c8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,096] Trial 14 finished with value: 15.095309707289742 and parameters: {'n_estimators': 1450, 'num_leaves': 124, 'max_depth': 6, 'learning_rate': 0.16244399476847823, 'feature_fraction': 0.7681881540884092, 'bagging_fraction': 0.6939740590096348, 'bagging_freq': 10, 'min_child_samples': 61, 'reg_alpha': 0.0002017260106010066, 'reg_lambda': 0.0010450965824495104}. Best is trial 11 with value: 15.089926682176632.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  30%|█████████████████▋                                         | 15/50 [00:01<00:02, 14.30it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  34%|████████████████████                                       | 17/50 [00:01<00:02, 14.30it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  34%|████████████████████                                       | 17/50 [00:01<00:02, 14.30it/s]
# 🏃 View run lgb_trial_15 at: http://127.0.0.1:5000/#/experiments/2/runs/11906f7e5dcf4a269ae494ccca06a253
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,174] Trial 15 finished with value: 15.094986064604422 and parameters: {'n_estimators': 931, 'num_leaves': 90, 'max_depth': 7, 'learning_rate': 0.13424744881016332, 'feature_fraction': 0.7120456215228355, 'bagging_fraction': 0.6621799168436411, 'bagging_freq': 10, 'min_child_samples': 73, 'reg_alpha': 3.743850241162189e-08, 'reg_lambda': 0.013857747028562}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_16 at: http://127.0.0.1:5000/#/experiments/2/runs/976a6dae49444769b4f273a2b49f9cb4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,235] Trial 16 finished with value: 15.093900276343211 and parameters: {'n_estimators': 1475, 'num_leaves': 149, 'max_depth': 3, 'learning_rate': 0.12372084215943373, 'feature_fraction': 0.8146940825837367, 'bagging_fraction': 0.6338188236094068, 'bagging_freq': 7, 'min_child_samples': 53, 'reg_alpha': 0.00011006394786040367, 'reg_lambda': 0.00014510409643486542}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_17 at: http://127.0.0.1:5000/#/experiments/2/runs/b8a08da863444a518de3e1cc20e0bd0d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,306] Trial 17 finished with value: 15.097735595274349 and parameters: {'n_estimators': 1246, 'num_leaves': 120, 'max_depth': 5, 'learning_rate': 0.23521848310604643, 'feature_fraction': 0.6697834121429656, 'bagging_fraction': 0.7132884025674471, 'bagging_freq': 9, 'min_child_samples': 52, 'reg_alpha': 2.45195558583042e-07, 'reg_lambda': 1.2750107672508652e-06}. Best is trial 11 with value: 15.089926682176632.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  38%|██████████████████████▍                                    | 19/50 [00:01<00:02, 13.93it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  38%|██████████████████████▍                                    | 19/50 [00:01<00:02, 13.93it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  42%|████████████████████████▊                                  | 21/50 [00:01<00:01, 14.53it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 11. Best value: 15.0899:  42%|████████████████████████▊                                  | 21/50 [00:01<00:01, 14.53it/s]
# 🏃 View run lgb_trial_18 at: http://127.0.0.1:5000/#/experiments/2/runs/42abe0057ff740159d7e4f6924a74f75
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,387] Trial 18 finished with value: 15.094333771055487 and parameters: {'n_estimators': 886, 'num_leaves': 96, 'max_depth': 7, 'learning_rate': 0.059806369932118436, 'feature_fraction': 0.7378338249452971, 'bagging_fraction': 0.651707776264195, 'bagging_freq': 9, 'min_child_samples': 73, 'reg_alpha': 0.0002132473907324716, 'reg_lambda': 0.017150203647830996}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_19 at: http://127.0.0.1:5000/#/experiments/2/runs/23e92bbf245b410db6275b78bde8e4ca
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,449] Trial 19 finished with value: 15.098552253483899 and parameters: {'n_estimators': 1628, 'num_leaves': 118, 'max_depth': 5, 'learning_rate': 0.11483956527362689, 'feature_fraction': 0.800089452221545, 'bagging_fraction': 0.7438072790603635, 'bagging_freq': 7, 'min_child_samples': 22, 'reg_alpha': 1.2689022000432541e-05, 'reg_lambda': 0.24483899465334572}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_20 at: http://127.0.0.1:5000/#/experiments/2/runs/edb11a3d4dae4fc68e012968cbbca259
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,512] Trial 20 finished with value: 15.094884767665782 and parameters: {'n_estimators': 1263, 'num_leaves': 109, 'max_depth': 4, 'learning_rate': 0.05182793708768527, 'feature_fraction': 0.7276990039439559, 'bagging_fraction': 0.6001695687988823, 'bagging_freq': 10, 'min_child_samples': 50, 'reg_alpha': 7.870523843939779, 'reg_lambda': 7.333935084586828e-05}. Best is trial 11 with value: 15.089926682176632.
# 🏃 View run lgb_trial_21 at: http://127.0.0.1:5000/#/experiments/2/runs/8be522f266784f51b35c1ee02393ebdb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,581] Trial 21 finished with value: 15.09344249077114 and parameters: {'n_estimators': 1489, 'num_leaves': 148, 'max_depth': 3, 'learning_rate': 0.11921508477901978, 'feature_fraction': 0.8076419367792632, 'bagging_fraction': 0.6426513871924437, 'bagging_freq': 7, 'min_child_samples': 52, 'reg_alpha': 0.0001077117424738094, 'reg_lambda': 0.0004055792241905628}. Best is trial 11 with value: 15.089926682176632.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 22. Best value: 15.0867:  46%|███████████████████████████▏                               | 23/50 [00:01<00:01, 13.75it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 22. Best value: 15.0867:  46%|███████████████████████████▏                               | 23/50 [00:01<00:01, 13.75it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 22. Best value: 15.0867:  50%|█████████████████████████████▌                             | 25/50 [00:01<00:01, 14.14it/s]
# 🏃 View run lgb_trial_22 at: http://127.0.0.1:5000/#/experiments/2/runs/1ffa4ecd184b4574ae7ff13d8f3698df
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,675] Trial 22 finished with value: 15.08672744898831 and parameters: {'n_estimators': 1573, 'num_leaves': 135, 'max_depth': 7, 'learning_rate': 0.19738557627814643, 'feature_fraction': 0.8024451295384638, 'bagging_fraction': 0.6452085548370768, 'bagging_freq': 6, 'min_child_samples': 59, 'reg_alpha': 0.0023260924388065303, 'reg_lambda': 0.0005905688356345736}. Best is trial 22 with value: 15.08672744898831.
# 🏃 View run lgb_trial_23 at: http://127.0.0.1:5000/#/experiments/2/runs/a51f9bd09da84172af67440a21fa9212
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,742] Trial 23 finished with value: 15.095447983145139 and parameters: {'n_estimators': 1616, 'num_leaves': 129, 'max_depth': 7, 'learning_rate': 0.2254188708334238, 'feature_fraction': 0.667410108093904, 'bagging_fraction': 0.6879493517779571, 'bagging_freq': 3, 'min_child_samples': 75, 'reg_alpha': 0.755770924352272, 'reg_lambda': 0.002775664734915601}. Best is trial 22 with value: 15.08672744898831.
# 🏃 View run lgb_trial_24 at: http://127.0.0.1:5000/#/experiments/2/runs/ef5fed74f3e54bf797f8ac82b9ffaa8f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,807] Trial 24 finished with value: 15.095863602085645 and parameters: {'n_estimators': 1288, 'num_leaves': 134, 'max_depth': 6, 'learning_rate': 0.2974644829508283, 'feature_fraction': 0.7860181317574729, 'bagging_fraction': 0.6252870642724525, 'bagging_freq': 1, 'min_child_samples': 61, 'reg_alpha': 0.001596880019124643, 'reg_lambda': 2.455533364018514e-06}. Best is trial 22 with value: 15.08672744898831.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 22. Best value: 15.0867:  50%|█████████████████████████████▌                             | 25/50 [00:01<00:01, 14.14it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 22. Best value: 15.0867:  54%|███████████████████████████████▊                           | 27/50 [00:02<00:01, 12.92it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 27. Best value: 15.0865:  54%|███████████████████████████████▊                           | 27/50 [00:02<00:01, 12.92it/s]
# 🏃 View run lgb_trial_25 at: http://127.0.0.1:5000/#/experiments/2/runs/e7ad8a5972604f9ea7260973c01669c0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,898] Trial 25 finished with value: 15.088940411476562 and parameters: {'n_estimators': 1015, 'num_leaves': 116, 'max_depth': 8, 'learning_rate': 0.15633818340097896, 'feature_fraction': 0.8463225320713784, 'bagging_fraction': 0.7147496385591114, 'bagging_freq': 6, 'min_child_samples': 64, 'reg_alpha': 0.7525155516610882, 'reg_lambda': 0.005524620855069011}. Best is trial 22 with value: 15.08672744898831.
# 🏃 View run lgb_trial_26 at: http://127.0.0.1:5000/#/experiments/2/runs/093a645f74a34d73872c17838f6b4959
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:04,993] Trial 26 finished with value: 15.090039411518758 and parameters: {'n_estimators': 976, 'num_leaves': 95, 'max_depth': 8, 'learning_rate': 0.16595096837452714, 'feature_fraction': 0.9217542918377113, 'bagging_fraction': 0.7448572296609568, 'bagging_freq': 6, 'min_child_samples': 45, 'reg_alpha': 1.0051343749592503, 'reg_lambda': 0.008165540967196324}. Best is trial 22 with value: 15.08672744898831.
# 🏃 View run lgb_trial_27 at: http://127.0.0.1:5000/#/experiments/2/runs/8a298bf6422b486a9009f1346163ab5c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,083] Trial 27 finished with value: 15.086548180675573 and parameters: {'n_estimators': 301, 'num_leaves': 109, 'max_depth': 8, 'learning_rate': 0.20854170771338257, 'feature_fraction': 0.8385760970916777, 'bagging_fraction': 0.7120968890162491, 'bagging_freq': 6, 'min_child_samples': 81, 'reg_alpha': 0.25089547426792824, 'reg_lambda': 0.09884269085048288}. Best is trial 27 with value: 15.086548180675573.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 27. Best value: 15.0865:  58%|██████████████████████████████████▏                        | 29/50 [00:02<00:01, 12.25it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 27. Best value: 15.0865:  58%|██████████████████████████████████▏                        | 29/50 [00:02<00:01, 12.25it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_28 at: http://127.0.0.1:5000/#/experiments/2/runs/3b6a998c9ceb487ba7f3b16a420a046d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,176] Trial 28 finished with value: 15.092592117404953 and parameters: {'n_estimators': 747, 'num_leaves': 83, 'max_depth': 8, 'learning_rate': 0.184785347276353, 'feature_fraction': 0.8385508625272152, 'bagging_fraction': 0.7790606510689909, 'bagging_freq': 6, 'min_child_samples': 81, 'reg_alpha': 0.23591520655791706, 'reg_lambda': 0.1491582391735308}. Best is trial 27 with value: 15.086548180675573.
# 🏃 View run lgb_trial_29 at: http://127.0.0.1:5000/#/experiments/2/runs/7887170e417e40768369944e29b29639
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,285] Trial 29 finished with value: 15.098570207626205 and parameters: {'n_estimators': 321, 'num_leaves': 82, 'max_depth': 10, 'learning_rate': 0.011638501091850408, 'feature_fraction': 0.8822983120089396, 'bagging_fraction': 0.7209231884890541, 'bagging_freq': 6, 'min_child_samples': 90, 'reg_alpha': 0.007993435758291458, 'reg_lambda': 1.2996447593009595}. Best is trial 27 with value: 15.086548180675573.
# 🏃 View run lgb_trial_30 at: http://127.0.0.1:5000/#/experiments/2/runs/794333219e774d60a9e98d8dbe02f2b2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 27. Best value: 15.0865:  62%|████████████████████████████████████▌                      | 31/50 [00:02<00:01, 11.57it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 31. Best value: 15.0863:  62%|████████████████████████████████████▌                      | 31/50 [00:02<00:01, 11.57it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 13:30:05,370] Trial 30 finished with value: 15.094989439653768 and parameters: {'n_estimators': 318, 'num_leaves': 107, 'max_depth': 10, 'learning_rate': 0.15012030468503493, 'feature_fraction': 0.9566567496042745, 'bagging_fraction': 0.7634344876256401, 'bagging_freq': 4, 'min_child_samples': 68, 'reg_alpha': 0.0010246639954790183, 'reg_lambda': 1.415324781167689e-08}. Best is trial 27 with value: 15.086548180675573.
# 🏃 View run lgb_trial_31 at: http://127.0.0.1:5000/#/experiments/2/runs/f1464844b28046f99450da4f52c571a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,495] Trial 31 finished with value: 15.086327486266248 and parameters: {'n_estimators': 1072, 'num_leaves': 112, 'max_depth': 8, 'learning_rate': 0.21638554680009717, 'feature_fraction': 0.8729091396782636, 'bagging_fraction': 0.7038405266950255, 'bagging_freq': 6, 'min_child_samples': 78, 'reg_alpha': 0.18615455586122034, 'reg_lambda': 0.05867483770401739}. Best is trial 31 with value: 15.086327486266248.
# Best trial: 31. Best value: 15.0863:  66%|██████████████████████████████████████▉                    | 33/50 [00:02<00:01, 10.78it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 31. Best value: 15.0863:  66%|██████████████████████████████████████▉                    | 33/50 [00:02<00:01, 10.78it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 31. Best value: 15.0863:  70%|█████████████████████████████████████████▎                 | 35/50 [00:02<00:01, 11.22it/s]
# 🏃 View run lgb_trial_32 at: http://127.0.0.1:5000/#/experiments/2/runs/647c07851a5646aa8b01d01e29b14bae
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,585] Trial 32 finished with value: 15.086573529899143 and parameters: {'n_estimators': 747, 'num_leaves': 126, 'max_depth': 8, 'learning_rate': 0.2062242280887894, 'feature_fraction': 0.879044805883969, 'bagging_fraction': 0.7077306243505577, 'bagging_freq': 6, 'min_child_samples': 78, 'reg_alpha': 0.1689771171542254, 'reg_lambda': 0.06562856357508745}. Best is trial 31 with value: 15.086327486266248.
# 🏃 View run lgb_trial_33 at: http://127.0.0.1:5000/#/experiments/2/runs/0cfba3c2d08d491ca367e1f9bbd3147a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,667] Trial 33 finished with value: 15.08682341025004 and parameters: {'n_estimators': 658, 'num_leaves': 128, 'max_depth': 8, 'learning_rate': 0.22404004254798016, 'feature_fraction': 0.8798856732280891, 'bagging_fraction': 0.6892092139783469, 'bagging_freq': 5, 'min_child_samples': 80, 'reg_alpha': 0.016971376031435594, 'reg_lambda': 0.8717360784920818}. Best is trial 31 with value: 15.086327486266248.
# 🏃 View run lgb_trial_34 at: http://127.0.0.1:5000/#/experiments/2/runs/25fd7e1ffcb44ee3a171ffa131f73383
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,747] Trial 34 finished with value: 15.093313214158238 and parameters: {'n_estimators': 857, 'num_leaves': 138, 'max_depth': 9, 'learning_rate': 0.20162634501746285, 'feature_fraction': 0.9270602784834295, 'bagging_fraction': 0.8074201567669642, 'bagging_freq': 4, 'min_child_samples': 87, 'reg_alpha': 0.06826186132645203, 'reg_lambda': 9.28783190706217}. Best is trial 31 with value: 15.086327486266248.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 31. Best value: 15.0863:  70%|█████████████████████████████████████████▎                 | 35/50 [00:02<00:01, 11.22it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  74%|███████████████████████████████████████████▋               | 37/50 [00:02<00:01, 11.56it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  74%|███████████████████████████████████████████▋               | 37/50 [00:03<00:01, 11.56it/s]
# 🏃 View run lgb_trial_35 at: http://127.0.0.1:5000/#/experiments/2/runs/b237e871784d4c4dba58fa28e43f241f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,821] Trial 35 finished with value: 15.094356442441873 and parameters: {'n_estimators': 775, 'num_leaves': 142, 'max_depth': 7, 'learning_rate': 0.20835219439070865, 'feature_fraction': 0.8223190362380535, 'bagging_fraction': 0.6680359510440729, 'bagging_freq': 7, 'min_child_samples': 95, 'reg_alpha': 0.28329522426123843, 'reg_lambda': 0.04523863438188141}. Best is trial 31 with value: 15.086327486266248.
# 🏃 View run lgb_trial_36 at: http://127.0.0.1:5000/#/experiments/2/runs/f8c83fcdbbaf44a39a22ede0c52bf9a8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:05,908] Trial 36 finished with value: 15.085382610879487 and parameters: {'n_estimators': 397, 'num_leaves': 101, 'max_depth': 9, 'learning_rate': 0.2505265409389303, 'feature_fraction': 0.9964154919860552, 'bagging_fraction': 0.7025254884414537, 'bagging_freq': 6, 'min_child_samples': 77, 'reg_alpha': 0.03383278468094123, 'reg_lambda': 0.2883463243113078}. Best is trial 36 with value: 15.085382610879487.
# 🏃 View run lgb_trial_37 at: http://127.0.0.1:5000/#/experiments/2/runs/bf89f60545c348eab9a56767ffa8b77a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,001] Trial 37 finished with value: 15.090222637982047 and parameters: {'n_estimators': 424, 'num_leaves': 72, 'max_depth': 9, 'learning_rate': 0.24520765638783296, 'feature_fraction': 0.9984394971295413, 'bagging_fraction': 0.7619649005804013, 'bagging_freq': 5, 'min_child_samples': 76, 'reg_alpha': 0.022783979338071365, 'reg_lambda': 0.4330046697637585}. Best is trial 36 with value: 15.085382610879487.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  78%|██████████████████████████████████████████████             | 39/50 [00:03<00:00, 11.48it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  78%|██████████████████████████████████████████████             | 39/50 [00:03<00:00, 11.48it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  82%|████████████████████████████████████████████████▍          | 41/50 [00:03<00:00, 11.47it/s]
# 🏃 View run lgb_trial_38 at: http://127.0.0.1:5000/#/experiments/2/runs/500e544a8ec74c07a5762ad017c91c5c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,085] Trial 38 finished with value: 15.095111191872185 and parameters: {'n_estimators': 408, 'num_leaves': 100, 'max_depth': 9, 'learning_rate': 0.09701167696859381, 'feature_fraction': 0.9044154040968413, 'bagging_fraction': 0.7132851159652771, 'bagging_freq': 4, 'min_child_samples': 87, 'reg_alpha': 0.2075487960997184, 'reg_lambda': 0.04643789569572687}. Best is trial 36 with value: 15.085382610879487.
# 🏃 View run lgb_trial_39 at: http://127.0.0.1:5000/#/experiments/2/runs/a3a24f39968041f093ef49c724a36ebc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,165] Trial 39 finished with value: 15.097668849239835 and parameters: {'n_estimators': 708, 'num_leaves': 88, 'max_depth': 11, 'learning_rate': 0.2627461961439079, 'feature_fraction': 0.8671317886076291, 'bagging_fraction': 0.8502897587167798, 'bagging_freq': 5, 'min_child_samples': 100, 'reg_alpha': 2.3986345430103615, 'reg_lambda': 2.4542422654651936}. Best is trial 36 with value: 15.085382610879487.
# 🏃 View run lgb_trial_40 at: http://127.0.0.1:5000/#/experiments/2/runs/f72f71be68cb4540a0fe965e2702ec68
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,259] Trial 40 finished with value: 15.088162084742276 and parameters: {'n_estimators': 609, 'num_leaves': 111, 'max_depth': 9, 'learning_rate': 0.14702663017583276, 'feature_fraction': 0.9578315357413655, 'bagging_fraction': 0.7315816154358435, 'bagging_freq': 7, 'min_child_samples': 78, 'reg_alpha': 0.02525010089162383, 'reg_lambda': 0.062494340166260216}. Best is trial 36 with value: 15.085382610879487.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 36. Best value: 15.0854:  82%|████████████████████████████████████████████████▍          | 41/50 [00:03<00:00, 11.47it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 42. Best value: 15.0853:  86%|██████████████████████████████████████████████████▋        | 43/50 [00:03<00:00, 11.17it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 43. Best value: 15.0848:  86%|██████████████████████████████████████████████████▋        | 43/50 [00:03<00:00, 11.17it/s]
# 🏃 View run lgb_trial_41 at: http://127.0.0.1:5000/#/experiments/2/runs/0d6fd007318747b08fd2eb2a7770148e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,357] Trial 41 finished with value: 15.08701121522302 and parameters: {'n_estimators': 405, 'num_leaves': 125, 'max_depth': 8, 'learning_rate': 0.18841675295275312, 'feature_fraction': 0.9360984688706917, 'bagging_fraction': 0.6997021908129392, 'bagging_freq': 6, 'min_child_samples': 69, 'reg_alpha': 0.10097234847524517, 'reg_lambda': 0.40152092528720623}. Best is trial 36 with value: 15.085382610879487.
# 🏃 View run lgb_trial_42 at: http://127.0.0.1:5000/#/experiments/2/runs/881a1189a0774bbcbbd8176308ec8172
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,450] Trial 42 finished with value: 15.08534589745279 and parameters: {'n_estimators': 1908, 'num_leaves': 132, 'max_depth': 10, 'learning_rate': 0.18591503466205503, 'feature_fraction': 0.8275149182237217, 'bagging_fraction': 0.6708163967403917, 'bagging_freq': 6, 'min_child_samples': 94, 'reg_alpha': 0.0008980639694271796, 'reg_lambda': 0.09074230752076408}. Best is trial 42 with value: 15.08534589745279.
# 🏃 View run lgb_trial_43 at: http://127.0.0.1:5000/#/experiments/2/runs/c0252d7f00e840178017c72c873a048e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,544] Trial 43 finished with value: 15.084849188603433 and parameters: {'n_estimators': 476, 'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.25342628508224596, 'feature_fraction': 0.897295820097218, 'bagging_fraction': 0.6753547114349022, 'bagging_freq': 5, 'min_child_samples': 94, 'reg_alpha': 0.010158785065655523, 'reg_lambda': 0.1100918457144567}. Best is trial 43 with value: 15.084849188603433.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848:  90%|█████████████████████████████████████████████████████      | 45/50 [00:03<00:00, 11.06it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848:  90%|█████████████████████████████████████████████████████      | 45/50 [00:03<00:00, 11.06it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848:  94%|███████████████████████████████████████████████████████▍   | 47/50 [00:03<00:00, 11.38it/s]
# 🏃 View run lgb_trial_44 at: http://127.0.0.1:5000/#/experiments/2/runs/58da55c02e5c43af982efbd52c36ffe8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,635] Trial 44 finished with value: 15.084773946906322 and parameters: {'n_estimators': 1742, 'num_leaves': 98, 'max_depth': 11, 'learning_rate': 0.2630004821086974, 'feature_fraction': 0.9074176269605729, 'bagging_fraction': 0.6767245641669775, 'bagging_freq': 5, 'min_child_samples': 93, 'reg_alpha': 0.0008266082899743408, 'reg_lambda': 2.665036043760968}. Best is trial 44 with value: 15.084773946906322.
# 🏃 View run lgb_trial_45 at: http://127.0.0.1:5000/#/experiments/2/runs/791eb79ca8dd4ec78552f4af7b84d2fd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,711] Trial 45 finished with value: 15.088031789979876 and parameters: {'n_estimators': 1942, 'num_leaves': 74, 'max_depth': 12, 'learning_rate': 0.25877733780311957, 'feature_fraction': 0.995058310911618, 'bagging_fraction': 0.6744591544993991, 'bagging_freq': 3, 'min_child_samples': 94, 'reg_alpha': 0.000727991645223525, 'reg_lambda': 3.204079825581396}. Best is trial 44 with value: 15.084773946906322.
# 🏃 View run lgb_trial_46 at: http://127.0.0.1:5000/#/experiments/2/runs/6fb4bf4bbe1249509ef6453b7f063768
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,798] Trial 46 finished with value: 15.085450161431751 and parameters: {'n_estimators': 1733, 'num_leaves': 97, 'max_depth': 11, 'learning_rate': 0.25847243853681967, 'feature_fraction': 0.9050779435720225, 'bagging_fraction': 0.6794697773010725, 'bagging_freq': 5, 'min_child_samples': 91, 'reg_alpha': 0.009221638461095123, 'reg_lambda': 0.7177098303307846}. Best is trial 44 with value: 15.084773946906322.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848:  94%|███████████████████████████████████████████████████████▍   | 47/50 [00:03<00:00, 11.38it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848:  98%|█████████████████████████████████████████████████████████▊ | 49/50 [00:04<00:00, 11.22it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 44. Best value: 15.0848: 100%|███████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.15it/s]
# 🏃 View run lgb_trial_47 at: http://127.0.0.1:5000/#/experiments/2/runs/665b9707546c438d90a7c29c7845693a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,903] Trial 47 finished with value: 15.098374871801392 and parameters: {'n_estimators': 1787, 'num_leaves': 98, 'max_depth': 11, 'learning_rate': 0.01849743151099246, 'feature_fraction': 0.9040604622386849, 'bagging_fraction': 0.6783596270310867, 'bagging_freq': 5, 'min_child_samples': 100, 'reg_alpha': 0.0005454450548038902, 'reg_lambda': 0.7069429857609619}. Best is trial 44 with value: 15.084773946906322.
# 🏃 View run lgb_trial_48 at: http://127.0.0.1:5000/#/experiments/2/runs/e63f55b92a5f4ab0a66863da69815d9c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:06,983] Trial 48 finished with value: 15.086748031771064 and parameters: {'n_estimators': 1873, 'num_leaves': 91, 'max_depth': 10, 'learning_rate': 0.2595512236408019, 'feature_fraction': 0.9752312424484498, 'bagging_fraction': 0.6561973697383069, 'bagging_freq': 4, 'min_child_samples': 95, 'reg_alpha': 0.008770957940279964, 'reg_lambda': 1.4772515156019774}. Best is trial 44 with value: 15.084773946906322.
# 🏃 View run lgb_trial_49 at: http://127.0.0.1:5000/#/experiments/2/runs/eb142ae78081498c842cae8195ec1dea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 13:30:07,074] Trial 49 finished with value: 15.093452287403103 and parameters: {'n_estimators': 1755, 'num_leaves': 61, 'max_depth': 11, 'learning_rate': 0.17525373545632486, 'feature_fraction': 0.941709655143041, 'bagging_fraction': 0.6174313767719601, 'bagging_freq': 3, 'min_child_samples': 91, 'reg_alpha': 3.126858734257253e-05, 'reg_lambda': 3.651607508994359}. Best is trial 44 with value: 15.084773946906322.
#
# ============================================================
# بهترین RMSE: 15.0848
#   n_estimators: 1742
#   num_leaves: 98
#   max_depth: 11
#   learning_rate: 0.2630004821086974
#   feature_fraction: 0.9074176269605729
#   bagging_fraction: 0.6767245641669775
#   bagging_freq: 5
#   min_child_samples: 93
#   reg_alpha: 0.0008266082899743408
#   reg_lambda: 2.665036043760968
# ============================================================
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 2026/08/02 13:30:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/08/02 13:30:11 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# مدل نهایی آموزش دیده و لاگ شد (هنوز در Registry ثبت نشده).
# 🏃 View run lightgbm_optuna_tuning_version_4 at: http://127.0.0.1:5000/#/experiments/2/runs/ddc2d16ec6ec47449e9c6dfa9ff3ae72
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
import mlflow
import optuna
import lightgbm as lgb
import joblib
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from mlflow.models import infer_signature


# ========================
# تابع هدف (Objective)
# ========================
def objective(trial, X_train, X_val, y_train, y_val):
    with mlflow.start_run(nested=True, run_name=f"lgb_trial_{trial.number}"):

        params = {
            'objective': 'regression',
            'metric': 'rmse',
            'n_estimators': trial.suggest_int('n_estimators', 300, 2000),
            'num_leaves': trial.suggest_int('num_leaves', 20, 150),
            'max_depth': trial.suggest_int('max_depth', 3, 12),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
            'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
            'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
            'random_state': 42,
            'n_jobs': 2,
            'verbose': -1
        }

        model = lgb.LGBMRegressor(**params)

        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
        )

        y_pred = model.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)

        mlflow.log_params(params)
        mlflow.log_metric("rmse", rmse)

        return rmse


# ========================
# تابع اصلی اجرای Tuning
# ========================
def run_lightgbm_optuna_tuning(X_train, X_val, y_train, y_val, n_trials=50):
    
    with mlflow.start_run(run_name="lightgbm_optuna_tuning_version_5"):
        
        study = optuna.create_study(
            direction="minimize",
            study_name="LightGBM_Hyperparameter_Tuning",
            pruner=optuna.pruners.MedianPruner()
        )

        study.optimize(
            lambda trial: objective(trial, X_train, X_val, y_train, y_val),
            n_trials=n_trials,
            show_progress_bar=True
        )

        print("\n" + "="*60)
        print(f"بهترین RMSE: {study.best_value:.4f}")
        for k, v in study.best_params.items():
            print(f"  {k}: {v}")
        print("="*60)

        mlflow.log_params(study.best_params)
        mlflow.log_metric("best_rmse", study.best_value)

        # ========================
        # آموزش مدل نهایی
        # ========================
        best_params = study.best_params.copy()
        best_params.update({
            'objective': 'regression',
            'metric': 'rmse',
            'random_state': 42,
            'n_jobs': 2,
            'verbose': -1
        })

        final_model = lgb.LGBMRegressor(**best_params)

        final_model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
        )

        # ارزیابی نهایی
        y_pred = final_model.predict(X_val)
        final_rmse = root_mean_squared_error(y_val, y_pred)
        final_mae = mean_absolute_error(y_val, y_pred)
        final_r2 = r2_score(y_val, y_pred)

        mlflow.log_metrics({
            "final_rmse": final_rmse,
            "final_mae": final_mae,
            "final_r2": final_r2
        })

        # ========================
        # ذخیره Artifactهای پیش‌پردازش (خیلی مهم)
        # ========================
        # ذخیره TargetEncoder
        joblib.dump(target_encoder, "target_encoder.pkl")
        mlflow.log_artifact("target_encoder.pkl", artifact_path="preprocessing")

        # ذخیره DictVectorizer
        joblib.dump(dv, "dict_vectorizer.pkl")
        mlflow.log_artifact("dict_vectorizer.pkl", artifact_path="preprocessing")

        # ========================
        # لاگ کردن مدل (با Signature و Metadata)
        # ========================
        signature = infer_signature(X_train, y_train)

        mlflow.sklearn.log_model(
            sk_model=final_model,
            artifact_path="model",
            signature=signature,
            skops_trusted_types=[
                "lightgbm.sklearn.LGBMRegressor",
                "lightgbm.basic.Booster",
                "collections.OrderedDict"
            ],
            metadata={
                "description": "LightGBM model trained with Optuna (50 trials)",
                "training_period": "AUG 2026",
                "feature_engineering": "Target Encoding on PU_DO + One-Hot on hour_category",
                "number_of_trials": 50,
                "best_rmse": round(final_rmse, 4),
                "n_jobs": 2,
                "preprocessing_artifacts": "target_encoder.pkl, dict_vectorizer.pkl"
            }
        )

        print("\n✅ مدل نهایی لاگ شد (همراه با Artifactهای پیش‌پردازش).")
        return final_model, study


# ========================
# اجرا
# ========================
if __name__ == "__main__":
    run_lightgbm_optuna_tuning(X_train, X_val, y_train, y_val, n_trials=50)
# Out:
# [I 2026-08-02 15:22:12,868] A new study created in memory with name: LightGBM_Hyperparameter_Tuning
#   0%|                                                                                                         | 0/50 [00:00<?, ?it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.099:   2%|█▏                                                            | 1/50 [00:00<00:10,  4.46it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 0. Best value: 15.099:   4%|██▍                                                           | 2/50 [00:00<00:07,  6.28it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_0 at: http://127.0.0.1:5000/#/experiments/2/runs/bfbf05ec73d3474281da53e3a001fef6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,111] Trial 0 finished with value: 15.099045791619655 and parameters: {'n_estimators': 1639, 'num_leaves': 123, 'max_depth': 4, 'learning_rate': 0.03517793448337852, 'feature_fraction': 0.9627041714543532, 'bagging_fraction': 0.645337225873977, 'bagging_freq': 7, 'min_child_samples': 86, 'reg_alpha': 2.927602376106012e-08, 'reg_lambda': 3.1816937494140714e-07}. Best is trial 0 with value: 15.099045791619655.
# 🏃 View run lgb_trial_1 at: http://127.0.0.1:5000/#/experiments/2/runs/1c00bc48031a45a682b7b25aec874654
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,225] Trial 1 finished with value: 15.100586433718917 and parameters: {'n_estimators': 1717, 'num_leaves': 136, 'max_depth': 5, 'learning_rate': 0.010352078612346504, 'feature_fraction': 0.7448797644833386, 'bagging_fraction': 0.796368829024153, 'bagging_freq': 7, 'min_child_samples': 89, 'reg_alpha': 1.6033753715244416e-06, 'reg_lambda': 4.755300432350633}. Best is trial 0 with value: 15.099045791619655.
# 🏃 View run lgb_trial_2 at: http://127.0.0.1:5000/#/experiments/2/runs/bb8bfaac7f7f4be1a13aa24b1f93de0b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 0. Best value: 15.099:   4%|██▍                                                           | 2/50 [00:00<00:07,  6.28it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 3. Best value: 15.0989:   8%|████▉                                                        | 4/50 [00:00<00:04,  9.31it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 3. Best value: 15.0989:  10%|██████                                                       | 5/50 [00:00<00:04,  9.07it/s]
# [I 2026-08-02 15:22:13,304] Trial 2 finished with value: 15.099465815781631 and parameters: {'n_estimators': 376, 'num_leaves': 124, 'max_depth': 3, 'learning_rate': 0.036433876414168245, 'feature_fraction': 0.710200383164074, 'bagging_fraction': 0.8654993723690343, 'bagging_freq': 6, 'min_child_samples': 55, 'reg_alpha': 4.6066516452634245e-07, 'reg_lambda': 1.2120563738509547}. Best is trial 0 with value: 15.099045791619655.
# 🏃 View run lgb_trial_3 at: http://127.0.0.1:5000/#/experiments/2/runs/df35ba1c2e93403e9fbcd892759ad36f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,379] Trial 3 finished with value: 15.098942493420497 and parameters: {'n_estimators': 1287, 'num_leaves': 140, 'max_depth': 6, 'learning_rate': 0.04309309812633864, 'feature_fraction': 0.9456334372809474, 'bagging_fraction': 0.6389462580622198, 'bagging_freq': 5, 'min_child_samples': 92, 'reg_alpha': 0.4732186471916553, 'reg_lambda': 3.809714180130294e-05}. Best is trial 3 with value: 15.098942493420497.
# 🏃 View run lgb_trial_4 at: http://127.0.0.1:5000/#/experiments/2/runs/bdc7e32b81e945ce888753c17dcd6b63
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,496] Trial 4 finished with value: 15.099543533956146 and parameters: {'n_estimators': 1511, 'num_leaves': 71, 'max_depth': 6, 'learning_rate': 0.027670430009197534, 'feature_fraction': 0.8099201105035356, 'bagging_fraction': 0.9596070029389774, 'bagging_freq': 6, 'min_child_samples': 90, 'reg_alpha': 0.0009127228790311899, 'reg_lambda': 1.6403310019851045e-08}. Best is trial 3 with value: 15.098942493420497.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 3. Best value: 15.0989:  10%|██████                                                       | 5/50 [00:00<00:04,  9.07it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 3. Best value: 15.0989:  14%|████████▌                                                    | 7/50 [00:00<00:03, 10.84it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 7. Best value: 15.0979:  14%|████████▌                                                    | 7/50 [00:00<00:03, 10.84it/s]
# 🏃 View run lgb_trial_5 at: http://127.0.0.1:5000/#/experiments/2/runs/bfc0e6b6eded4538b3192dbe070c6bf1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,562] Trial 5 finished with value: 15.100983093085457 and parameters: {'n_estimators': 400, 'num_leaves': 118, 'max_depth': 5, 'learning_rate': 0.16396164919493555, 'feature_fraction': 0.8032625579051597, 'bagging_fraction': 0.9578158860900332, 'bagging_freq': 7, 'min_child_samples': 96, 'reg_alpha': 1.0738051360706103e-08, 'reg_lambda': 0.0002095405343049548}. Best is trial 3 with value: 15.098942493420497.
# 🏃 View run lgb_trial_6 at: http://127.0.0.1:5000/#/experiments/2/runs/e3832d983fe644e3ba6f78e810c652da
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,639] Trial 6 finished with value: 15.099815742388266 and parameters: {'n_estimators': 970, 'num_leaves': 119, 'max_depth': 5, 'learning_rate': 0.030256954487001875, 'feature_fraction': 0.6711049654107706, 'bagging_fraction': 0.9715851831646395, 'bagging_freq': 2, 'min_child_samples': 91, 'reg_alpha': 3.0531043937846325e-05, 'reg_lambda': 3.4435661285994537e-07}. Best is trial 3 with value: 15.098942493420497.
# 🏃 View run lgb_trial_7 at: http://127.0.0.1:5000/#/experiments/2/runs/c0f8a2e274374a65a9deca9697b4cef2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,726] Trial 7 finished with value: 15.097882649879914 and parameters: {'n_estimators': 1418, 'num_leaves': 88, 'max_depth': 3, 'learning_rate': 0.01995186602203593, 'feature_fraction': 0.914768122002984, 'bagging_fraction': 0.6800450094739493, 'bagging_freq': 7, 'min_child_samples': 32, 'reg_alpha': 3.4467424465467464e-07, 'reg_lambda': 1.1642364313231918e-08}. Best is trial 7 with value: 15.097882649879914.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 7. Best value: 15.0979:  18%|██████████▉                                                  | 9/50 [00:00<00:03, 11.42it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 7. Best value: 15.0979:  18%|██████████▉                                                  | 9/50 [00:01<00:03, 11.42it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_8 at: http://127.0.0.1:5000/#/experiments/2/runs/e0decfc20a8d48df91cf43fdccc2e97a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,800] Trial 8 finished with value: 15.100813564680074 and parameters: {'n_estimators': 1442, 'num_leaves': 145, 'max_depth': 6, 'learning_rate': 0.0823424047378466, 'feature_fraction': 0.6591276160946204, 'bagging_fraction': 0.989808126084019, 'bagging_freq': 6, 'min_child_samples': 56, 'reg_alpha': 6.189564505483224e-06, 'reg_lambda': 4.597133206350681e-06}. Best is trial 7 with value: 15.097882649879914.
# 🏃 View run lgb_trial_9 at: http://127.0.0.1:5000/#/experiments/2/runs/27bec8855a6941fe882769062fded6fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:13,908] Trial 9 finished with value: 15.099611812792752 and parameters: {'n_estimators': 1012, 'num_leaves': 141, 'max_depth': 12, 'learning_rate': 0.012330733132689918, 'feature_fraction': 0.7840626097043609, 'bagging_fraction': 0.8764328897732869, 'bagging_freq': 4, 'min_child_samples': 33, 'reg_alpha': 0.0006980936360961816, 'reg_lambda': 8.40062445825094e-05}. Best is trial 7 with value: 15.097882649879914.
# 🏃 View run lgb_trial_10 at: http://127.0.0.1:5000/#/experiments/2/runs/91a6bdaf07fc4587ab8203c5f66b7bbd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 10. Best value: 15.0957:  22%|████████████▉                                              | 11/50 [00:01<00:03, 10.95it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 10. Best value: 15.0957:  22%|████████████▉                                              | 11/50 [00:01<00:03, 10.95it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 12. Best value: 15.0956:  26%|███████████████▎                                           | 13/50 [00:01<00:03, 11.88it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 15:22:13,996] Trial 10 finished with value: 15.09567604131172 and parameters: {'n_estimators': 1969, 'num_leaves': 20, 'max_depth': 9, 'learning_rate': 0.2998751965432645, 'feature_fraction': 0.8943741978257576, 'bagging_fraction': 0.7330597963120972, 'bagging_freq': 10, 'min_child_samples': 10, 'reg_alpha': 4.131222461639486, 'reg_lambda': 0.021251919887006077}. Best is trial 10 with value: 15.09567604131172.
# 🏃 View run lgb_trial_11 at: http://127.0.0.1:5000/#/experiments/2/runs/00c47dacfc2a4469920313a1feea70a8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,064] Trial 11 finished with value: 15.097382188631038 and parameters: {'n_estimators': 1972, 'num_leaves': 21, 'max_depth': 9, 'learning_rate': 0.2956181738760266, 'feature_fraction': 0.8829502586779825, 'bagging_fraction': 0.7215892532150883, 'bagging_freq': 10, 'min_child_samples': 12, 'reg_alpha': 9.56987126317962, 'reg_lambda': 0.01283936926604509}. Best is trial 10 with value: 15.09567604131172.
# 🏃 View run lgb_trial_12 at: http://127.0.0.1:5000/#/experiments/2/runs/a3eb3c6e71644eaf8ba4e08c30049a57
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,137] Trial 12 finished with value: 15.09555932660782 and parameters: {'n_estimators': 1978, 'num_leaves': 23, 'max_depth': 9, 'learning_rate': 0.29656010678977085, 'feature_fraction': 0.8756126310187733, 'bagging_fraction': 0.7344675958463377, 'bagging_freq': 10, 'min_child_samples': 11, 'reg_alpha': 4.572610751376267, 'reg_lambda': 0.0181783006128506}. Best is trial 12 with value: 15.09555932660782.
# Best trial: 12. Best value: 15.0956:  26%|███████████████▎                                           | 13/50 [00:01<00:03, 11.88it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 12. Best value: 15.0956:  30%|█████████████████▋                                         | 15/50 [00:01<00:02, 12.20it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  30%|█████████████████▋                                         | 15/50 [00:01<00:02, 12.20it/s]
# 🏃 View run lgb_trial_13 at: http://127.0.0.1:5000/#/experiments/2/runs/0b4aa3eb494f4c8fb1f268895efa793f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,227] Trial 13 finished with value: 15.101258236691837 and parameters: {'n_estimators': 1890, 'num_leaves': 20, 'max_depth': 9, 'learning_rate': 0.26079505748527343, 'feature_fraction': 0.8658615675505162, 'bagging_fraction': 0.7446335009458857, 'bagging_freq': 10, 'min_child_samples': 16, 'reg_alpha': 0.2264791337616805, 'reg_lambda': 0.01709527467566379}. Best is trial 12 with value: 15.09555932660782.
# 🏃 View run lgb_trial_14 at: http://127.0.0.1:5000/#/experiments/2/runs/99c7904aa12140f8aef372673d9a1c33
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,292] Trial 14 finished with value: 15.100864004338796 and parameters: {'n_estimators': 1970, 'num_leaves': 39, 'max_depth': 9, 'learning_rate': 0.14029648151607158, 'feature_fraction': 0.8469359145553229, 'bagging_fraction': 0.782928192540174, 'bagging_freq': 9, 'min_child_samples': 25, 'reg_alpha': 5.133277263759811, 'reg_lambda': 0.023847771061284717}. Best is trial 12 with value: 15.09555932660782.
# 🏃 View run lgb_trial_15 at: http://127.0.0.1:5000/#/experiments/2/runs/64c9159184fd42a192cc330af7ce8711
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,372] Trial 15 finished with value: 15.090294251330816 and parameters: {'n_estimators': 1753, 'num_leaves': 45, 'max_depth': 11, 'learning_rate': 0.17206995227412197, 'feature_fraction': 0.9954574773546991, 'bagging_fraction': 0.6053763991144085, 'bagging_freq': 9, 'min_child_samples': 11, 'reg_alpha': 0.049771978768072274, 'reg_lambda': 0.21237643335064327}. Best is trial 15 with value: 15.090294251330816.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  34%|████████████████████                                       | 17/50 [00:01<00:02, 12.25it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  34%|████████████████████                                       | 17/50 [00:01<00:02, 12.25it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  38%|██████████████████████▍                                    | 19/50 [00:01<00:02, 12.85it/s]
# 🏃 View run lgb_trial_16 at: http://127.0.0.1:5000/#/experiments/2/runs/9b6070251b904e119250e8add1426ac7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,454] Trial 16 finished with value: 15.09312596071706 and parameters: {'n_estimators': 1748, 'num_leaves': 50, 'max_depth': 11, 'learning_rate': 0.1479886634912212, 'feature_fraction': 0.9968295369246559, 'bagging_fraction': 0.6273357557709773, 'bagging_freq': 9, 'min_child_samples': 43, 'reg_alpha': 0.02037638903190887, 'reg_lambda': 0.39901481506868025}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_17 at: http://127.0.0.1:5000/#/experiments/2/runs/9508cff0c2414c8085a2ccc46825c89f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,524] Trial 17 finished with value: 15.09412901243777 and parameters: {'n_estimators': 1178, 'num_leaves': 55, 'max_depth': 12, 'learning_rate': 0.07016469439438767, 'feature_fraction': 0.9857208294721712, 'bagging_fraction': 0.6043682208548248, 'bagging_freq': 8, 'min_child_samples': 51, 'reg_alpha': 0.007336084445903831, 'reg_lambda': 0.5149166201149417}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_18 at: http://127.0.0.1:5000/#/experiments/2/runs/1c16a52a4c6b4703b17488233757f15e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,593] Trial 18 finished with value: 15.090806006729387 and parameters: {'n_estimators': 1712, 'num_leaves': 61, 'max_depth': 11, 'learning_rate': 0.15484817337367773, 'feature_fraction': 0.9962267979903893, 'bagging_fraction': 0.6067443702788968, 'bagging_freq': 9, 'min_child_samples': 70, 'reg_alpha': 0.02222566795613214, 'reg_lambda': 0.22780140432130536}. Best is trial 15 with value: 15.090294251330816.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  38%|██████████████████████▍                                    | 19/50 [00:01<00:02, 12.85it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  42%|████████████████████████▊                                  | 21/50 [00:01<00:02, 13.52it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  42%|████████████████████████▊                                  | 21/50 [00:01<00:02, 13.52it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_19 at: http://127.0.0.1:5000/#/experiments/2/runs/d84bc5db9c804d8c94fe2a2d7145b534
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,668] Trial 19 finished with value: 15.097878152912012 and parameters: {'n_estimators': 1659, 'num_leaves': 85, 'max_depth': 11, 'learning_rate': 0.09165840564077105, 'feature_fraction': 0.9391967577940392, 'bagging_fraction': 0.6824471249173838, 'bagging_freq': 1, 'min_child_samples': 71, 'reg_alpha': 0.011236949829830397, 'reg_lambda': 0.0016674395883988548}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_20 at: http://127.0.0.1:5000/#/experiments/2/runs/1568aad15e8f42e59d8cf27015fd9452
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,724] Trial 20 finished with value: 15.095613569530006 and parameters: {'n_estimators': 720, 'num_leaves': 71, 'max_depth': 11, 'learning_rate': 0.19050459401826175, 'feature_fraction': 0.6011932584996008, 'bagging_fraction': 0.6785636309077161, 'bagging_freq': 8, 'min_child_samples': 65, 'reg_alpha': 0.00019131344098427379, 'reg_lambda': 6.610721155827926}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_21 at: http://127.0.0.1:5000/#/experiments/2/runs/6b88901434ff48a8a08d3a1a576130b6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,797] Trial 21 finished with value: 15.091182718954983 and parameters: {'n_estimators': 1750, 'num_leaves': 48, 'max_depth': 11, 'learning_rate': 0.1264806696342583, 'feature_fraction': 0.9974684280220959, 'bagging_fraction': 0.6013849528384809, 'bagging_freq': 9, 'min_child_samples': 42, 'reg_alpha': 0.05665769287481861, 'reg_lambda': 0.22215853559713186}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_22 at: http://127.0.0.1:5000/#/experiments/2/runs/eaef41f27529400ab20dffc7578ef5f6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 15. Best value: 15.0903:  46%|███████████████████████████▏                               | 23/50 [00:01<00:01, 13.64it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 15. Best value: 15.0903:  46%|███████████████████████████▏                               | 23/50 [00:02<00:01, 13.64it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  50%|██████████████████████████████▌                              | 25/50 [00:02<00:01, 14.26it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 15:22:14,867] Trial 22 finished with value: 15.091400115744698 and parameters: {'n_estimators': 1789, 'num_leaves': 41, 'max_depth': 10, 'learning_rate': 0.11704790408830103, 'feature_fraction': 0.98774799707614, 'bagging_fraction': 0.6049186394073506, 'bagging_freq': 9, 'min_child_samples': 75, 'reg_alpha': 0.08175159805247074, 'reg_lambda': 0.1571328535324569}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_23 at: http://127.0.0.1:5000/#/experiments/2/runs/1bf26dc572aa4f36b5aa8fa6b09fbe2f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,931] Trial 23 finished with value: 15.094578804609059 and parameters: {'n_estimators': 1565, 'num_leaves': 63, 'max_depth': 10, 'learning_rate': 0.06090108899907486, 'feature_fraction': 0.9335134849320382, 'bagging_fraction': 0.6551527968943561, 'bagging_freq': 8, 'min_child_samples': 40, 'reg_alpha': 0.0025746639983469668, 'reg_lambda': 0.13121427404726183}. Best is trial 15 with value: 15.090294251330816.
# 🏃 View run lgb_trial_24 at: http://127.0.0.1:5000/#/experiments/2/runs/29f144d9a7294816816917ee1b19f44d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:14,993] Trial 24 finished with value: 15.090007115716121 and parameters: {'n_estimators': 1793, 'num_leaves': 37, 'max_depth': 12, 'learning_rate': 0.21393617307806176, 'feature_fraction': 0.9656538265286976, 'bagging_fraction': 0.6019988983373444, 'bagging_freq': 9, 'min_child_samples': 23, 'reg_alpha': 0.0524422006365794, 'reg_lambda': 0.0017203657703242505}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_25 at: http://127.0.0.1:5000/#/experiments/2/runs/8771421d86914e70ba8555997327c838
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 24. Best value: 15.09:  50%|██████████████████████████████▌                              | 25/50 [00:02<00:01, 14.26it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  54%|████████████████████████████████▉                            | 27/50 [00:02<00:01, 13.83it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  54%|████████████████████████████████▉                            | 27/50 [00:02<00:01, 13.83it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 15:22:15,078] Trial 25 finished with value: 15.095049650102162 and parameters: {'n_estimators': 1300, 'num_leaves': 34, 'max_depth': 12, 'learning_rate': 0.20497192884059523, 'feature_fraction': 0.9609757231107148, 'bagging_fraction': 0.6636962246934315, 'bagging_freq': 8, 'min_child_samples': 20, 'reg_alpha': 0.37377609972650905, 'reg_lambda': 0.0006878918583982336}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_26 at: http://127.0.0.1:5000/#/experiments/2/runs/0e6c59cfba4941ebaf7382999bc0a971
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,148] Trial 26 finished with value: 15.098718669997957 and parameters: {'n_estimators': 1842, 'num_leaves': 87, 'max_depth': 10, 'learning_rate': 0.20147303795002308, 'feature_fraction': 0.9120470880087016, 'bagging_fraction': 0.705446876003424, 'bagging_freq': 9, 'min_child_samples': 24, 'reg_alpha': 0.00010392780136649203, 'reg_lambda': 0.0023893472322771498}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_27 at: http://127.0.0.1:5000/#/experiments/2/runs/e1a50d37904d452a8ca3d63628fcefb4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,217] Trial 27 finished with value: 15.096126889713169 and parameters: {'n_estimators': 1598, 'num_leaves': 61, 'max_depth': 8, 'learning_rate': 0.10638773972021527, 'feature_fraction': 0.9636782434967172, 'bagging_fraction': 0.6299074859436434, 'bagging_freq': 8, 'min_child_samples': 80, 'reg_alpha': 0.7930202725815458, 'reg_lambda': 0.0025884815606154335}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_28 at: http://127.0.0.1:5000/#/experiments/2/runs/82086d2fae6641be865679bcf11bd827
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Best trial: 24. Best value: 15.09:  58%|███████████████████████████████████▍                         | 29/50 [00:02<00:01, 14.12it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  58%|███████████████████████████████████▍                         | 29/50 [00:02<00:01, 14.12it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  62%|█████████████████████████████████████▊                       | 31/50 [00:02<00:01, 14.29it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 15:22:15,283] Trial 28 finished with value: 15.091398796313031 and parameters: {'n_estimators': 1370, 'num_leaves': 32, 'max_depth': 12, 'learning_rate': 0.19490607794529785, 'feature_fraction': 0.9129910376780894, 'bagging_fraction': 0.6264938688293934, 'bagging_freq': 10, 'min_child_samples': 28, 'reg_alpha': 0.06850205366614308, 'reg_lambda': 1.3388178225630444e-05}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_29 at: http://127.0.0.1:5000/#/experiments/2/runs/e54a0cac7f524d62926138f05514b39c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,345] Trial 29 finished with value: 15.096067996326079 and parameters: {'n_estimators': 1603, 'num_leaves': 80, 'max_depth': 8, 'learning_rate': 0.23217200574618785, 'feature_fraction': 0.9648370177664538, 'bagging_fraction': 0.6492776065832202, 'bagging_freq': 9, 'min_child_samples': 65, 'reg_alpha': 0.002782213471730186, 'reg_lambda': 1.4122639818377718}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_30 at: http://127.0.0.1:5000/#/experiments/2/runs/694de82af97d4ea8ad95dc7e75e31f71
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,419] Trial 30 finished with value: 15.09692037924666 and parameters: {'n_estimators': 1859, 'num_leaves': 45, 'max_depth': 11, 'learning_rate': 0.10048796606704763, 'feature_fraction': 0.9709478809601595, 'bagging_fraction': 0.7026323023941788, 'bagging_freq': 3, 'min_child_samples': 18, 'reg_alpha': 0.03614882161240511, 'reg_lambda': 0.08858850145460338}. Best is trial 24 with value: 15.090007115716121.
# Best trial: 24. Best value: 15.09:  62%|█████████████████████████████████████▊                       | 31/50 [00:02<00:01, 14.29it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  66%|████████████████████████████████████████▎                    | 33/50 [00:02<00:01, 14.40it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  66%|████████████████████████████████████████▎                    | 33/50 [00:02<00:01, 14.40it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 🏃 View run lgb_trial_31 at: http://127.0.0.1:5000/#/experiments/2/runs/feefa133d12f447f98d28149e86b32b6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,494] Trial 31 finished with value: 15.091285155814315 and parameters: {'n_estimators': 1718, 'num_leaves': 54, 'max_depth': 11, 'learning_rate': 0.12525411736398104, 'feature_fraction': 0.9950799325662383, 'bagging_fraction': 0.6032434214351265, 'bagging_freq': 9, 'min_child_samples': 39, 'reg_alpha': 0.1142556674606766, 'reg_lambda': 0.0922711629505509}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_32 at: http://127.0.0.1:5000/#/experiments/2/runs/24fbc89d0d48483d82c46a671f6a56f1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,555] Trial 32 finished with value: 15.090789229840446 and parameters: {'n_estimators': 1693, 'num_leaves': 98, 'max_depth': 10, 'learning_rate': 0.16694865849447227, 'feature_fraction': 0.9995778543625814, 'bagging_fraction': 0.6031265177040428, 'bagging_freq': 8, 'min_child_samples': 50, 'reg_alpha': 0.008902907725276866, 'reg_lambda': 2.374007053216585}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_33 at: http://127.0.0.1:5000/#/experiments/2/runs/f78dafc78de14dee98787b384a62c886
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,621] Trial 33 finished with value: 15.096318800507001 and parameters: {'n_estimators': 1661, 'num_leaves': 99, 'max_depth': 10, 'learning_rate': 0.1588127519568667, 'feature_fraction': 0.9413554034445811, 'bagging_fraction': 0.6302915987548333, 'bagging_freq': 7, 'min_child_samples': 49, 'reg_alpha': 0.004676347790707218, 'reg_lambda': 2.316528706108324}. Best is trial 24 with value: 15.090007115716121.
# Best trial: 24. Best value: 15.09:  70%|██████████████████████████████████████████▋                  | 35/50 [00:02<00:01, 14.42it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  70%|██████████████████████████████████████████▋                  | 35/50 [00:02<00:01, 14.42it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 24. Best value: 15.09:  74%|█████████████████████████████████████████████▏               | 37/50 [00:02<00:00, 14.78it/s]
# 🏃 View run lgb_trial_34 at: http://127.0.0.1:5000/#/experiments/2/runs/351861f2f88b4821b1cb02a787b22abc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,693] Trial 34 finished with value: 15.095053605694856 and parameters: {'n_estimators': 1515, 'num_leaves': 109, 'max_depth': 12, 'learning_rate': 0.1715984938300071, 'feature_fraction': 0.9654592415017947, 'bagging_fraction': 0.6632898037432375, 'bagging_freq': 8, 'min_child_samples': 82, 'reg_alpha': 0.731370790763832, 'reg_lambda': 5.045238901992242}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_35 at: http://127.0.0.1:5000/#/experiments/2/runs/d324e70292664430a44a52cba972976c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,757] Trial 35 finished with value: 15.095701686114246 and parameters: {'n_estimators': 1855, 'num_leaves': 30, 'max_depth': 10, 'learning_rate': 0.22085602883610825, 'feature_fraction': 0.9369173085301543, 'bagging_fraction': 0.6283479262792211, 'bagging_freq': 7, 'min_child_samples': 60, 'reg_alpha': 0.0007372614190677307, 'reg_lambda': 1.080625346268272}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_36 at: http://127.0.0.1:5000/#/experiments/2/runs/b888eed44c1f48149e67acbe4384b2bf
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,821] Trial 36 finished with value: 15.098274351878116 and parameters: {'n_estimators': 1484, 'num_leaves': 128, 'max_depth': 8, 'learning_rate': 0.05687637249941523, 'feature_fraction': 0.9762718244648553, 'bagging_fraction': 0.6467792630817923, 'bagging_freq': 6, 'min_child_samples': 31, 'reg_alpha': 0.02461067977307811, 'reg_lambda': 8.566419195972138}. Best is trial 24 with value: 15.090007115716121.
# 🏃 View run lgb_trial_37 at: http://127.0.0.1:5000/#/experiments/2/runs/0f83dc89570c4669a2bb87ad429c2f32
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 37. Best value: 15.0894:  74%|███████████████████████████████████████████▋               | 37/50 [00:03<00:00, 14.78it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 37. Best value: 15.0894:  78%|██████████████████████████████████████████████             | 39/50 [00:03<00:00, 14.77it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  78%|██████████████████████████████████████████████             | 39/50 [00:03<00:00, 14.77it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [I 2026-08-02 15:22:15,890] Trial 37 finished with value: 15.08939915392234 and parameters: {'n_estimators': 1664, 'num_leaves': 99, 'max_depth': 12, 'learning_rate': 0.2383315663050205, 'feature_fraction': 0.9518645709467924, 'bagging_fraction': 0.613132941826351, 'bagging_freq': 8, 'min_child_samples': 22, 'reg_alpha': 1.1482637925273296, 'reg_lambda': 0.00043044064025579844}. Best is trial 37 with value: 15.08939915392234.
# 🏃 View run lgb_trial_38 at: http://127.0.0.1:5000/#/experiments/2/runs/129a66c3298f4e589b6350325fd38876
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:15,956] Trial 38 finished with value: 15.09609490389175 and parameters: {'n_estimators': 1333, 'num_leaves': 100, 'max_depth': 12, 'learning_rate': 0.2524443585426627, 'feature_fraction': 0.9098678181741475, 'bagging_fraction': 0.6984802537937111, 'bagging_freq': 7, 'min_child_samples': 23, 'reg_alpha': 2.085230701399494, 'reg_lambda': 2.4899168122628115e-06}. Best is trial 37 with value: 15.08939915392234.
# 🏃 View run lgb_trial_39 at: http://127.0.0.1:5000/#/experiments/2/runs/83b3d085f3b44275ada69ec04b4ec7b9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,052] Trial 39 finished with value: 15.086310672033571 and parameters: {'n_estimators': 1575, 'num_leaves': 97, 'max_depth': 12, 'learning_rate': 0.17075199793100013, 'feature_fraction': 0.8380437967774259, 'bagging_fraction': 0.6715444343299501, 'bagging_freq': 6, 'min_child_samples': 36, 'reg_alpha': 0.16046816541103484, 'reg_lambda': 4.5718392090250646e-05}. Best is trial 39 with value: 15.086310672033571.
# Best trial: 39. Best value: 15.0863:  82%|████████████████████████████████████████████████▍          | 41/50 [00:03<00:00, 13.59it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  82%|████████████████████████████████████████████████▍          | 41/50 [00:03<00:00, 13.59it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  86%|██████████████████████████████████████████████████▋        | 43/50 [00:03<00:00, 12.99it/s]
# 🏃 View run lgb_trial_40 at: http://127.0.0.1:5000/#/experiments/2/runs/0dda79500a7c446e9c5d8f3d8ffa8e85
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,131] Trial 40 finished with value: 15.098821833818366 and parameters: {'n_estimators': 1188, 'num_leaves': 129, 'max_depth': 12, 'learning_rate': 0.13443248455075096, 'feature_fraction': 0.8334750859996743, 'bagging_fraction': 0.7774122596296522, 'bagging_freq': 5, 'min_child_samples': 36, 'reg_alpha': 1.2936316209611196, 'reg_lambda': 0.00025915803242678814}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_41 at: http://127.0.0.1:5000/#/experiments/2/runs/c4a22cf924a84819abcfeb7116042541
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,214] Trial 41 finished with value: 15.087181837107002 and parameters: {'n_estimators': 1650, 'num_leaves': 100, 'max_depth': 12, 'learning_rate': 0.18066111391278664, 'feature_fraction': 0.7216040942697981, 'bagging_fraction': 0.6728697814927933, 'bagging_freq': 5, 'min_child_samples': 46, 'reg_alpha': 0.21676578752077966, 'reg_lambda': 7.619720320313074e-05}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_42 at: http://127.0.0.1:5000/#/experiments/2/runs/24ecb3f2ee0846bea485d0c093ac9599
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,301] Trial 42 finished with value: 15.088946476461018 and parameters: {'n_estimators': 1550, 'num_leaves': 112, 'max_depth': 12, 'learning_rate': 0.18157382037950887, 'feature_fraction': 0.7484005939309977, 'bagging_fraction': 0.674108255625161, 'bagging_freq': 4, 'min_child_samples': 28, 'reg_alpha': 0.20024872907896485, 'reg_lambda': 3.29046926876025e-05}. Best is trial 39 with value: 15.086310672033571.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  86%|██████████████████████████████████████████████████▋        | 43/50 [00:03<00:00, 12.99it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  90%|█████████████████████████████████████████████████████      | 45/50 [00:03<00:00, 12.39it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  90%|█████████████████████████████████████████████████████      | 45/50 [00:03<00:00, 12.39it/s]
# 🏃 View run lgb_trial_43 at: http://127.0.0.1:5000/#/experiments/2/runs/9f015b56886049d5bd75cde346d7d676
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,398] Trial 43 finished with value: 15.088363054868113 and parameters: {'n_estimators': 1544, 'num_leaves': 114, 'max_depth': 12, 'learning_rate': 0.21963713811077326, 'feature_fraction': 0.7330715895738408, 'bagging_fraction': 0.6802227686692149, 'bagging_freq': 4, 'min_child_samples': 46, 'reg_alpha': 0.24413128812435558, 'reg_lambda': 4.057010670589411e-05}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_44 at: http://127.0.0.1:5000/#/experiments/2/runs/a8dc92c7b197403bb4799140a2eca9bd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,479] Trial 44 finished with value: 15.087869395449344 and parameters: {'n_estimators': 1431, 'num_leaves': 111, 'max_depth': 12, 'learning_rate': 0.2530248245427115, 'feature_fraction': 0.7391738377706909, 'bagging_fraction': 0.6814724534838844, 'bagging_freq': 4, 'min_child_samples': 46, 'reg_alpha': 0.275632728578525, 'reg_lambda': 3.8591129986136665e-05}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_45 at: http://127.0.0.1:5000/#/experiments/2/runs/290b0452cf474b0fbc4fb79ff9caaa52
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,566] Trial 45 finished with value: 15.089245438169412 and parameters: {'n_estimators': 1407, 'num_leaves': 111, 'max_depth': 12, 'learning_rate': 0.25588850872042784, 'feature_fraction': 0.7350848801780481, 'bagging_fraction': 0.7532719064186836, 'bagging_freq': 4, 'min_child_samples': 45, 'reg_alpha': 0.34677193962258424, 'reg_lambda': 5.847518417968247e-05}. Best is trial 39 with value: 15.086310672033571.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  94%|███████████████████████████████████████████████████████▍   | 47/50 [00:03<00:00, 11.32it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  94%|███████████████████████████████████████████████████████▍   | 47/50 [00:03<00:00, 11.32it/s]/Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863:  98%|█████████████████████████████████████████████████████████▊ | 49/50 [00:03<00:00, 11.82it/s]
# 🏃 View run lgb_trial_46 at: http://127.0.0.1:5000/#/experiments/2/runs/92c1509a04334016a3b0439522b15c84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,692] Trial 46 finished with value: 15.096370464488372 and parameters: {'n_estimators': 1222, 'num_leaves': 110, 'max_depth': 12, 'learning_rate': 0.18658808045117242, 'feature_fraction': 0.772986962873633, 'bagging_fraction': 0.8431903194521301, 'bagging_freq': 5, 'min_child_samples': 56, 'reg_alpha': 0.18719473302204634, 'reg_lambda': 2.1763051569408657e-05}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_47 at: http://127.0.0.1:5000/#/experiments/2/runs/7979c510b875401b8e713eb8c0ae1a69
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,772] Trial 47 finished with value: 15.0880681259283 and parameters: {'n_estimators': 1065, 'num_leaves': 115, 'max_depth': 11, 'learning_rate': 0.2744238955342729, 'feature_fraction': 0.7065193470803297, 'bagging_fraction': 0.7210399298514242, 'bagging_freq': 4, 'min_child_samples': 46, 'reg_alpha': 0.1828211266376274, 'reg_lambda': 1.1841835905484676e-06}. Best is trial 39 with value: 15.086310672033571.
# 🏃 View run lgb_trial_48 at: http://127.0.0.1:5000/#/experiments/2/runs/584f649bdaae4a67a18f1d1de9fe98ba
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,844] Trial 48 finished with value: 15.094943099989516 and parameters: {'n_estimators': 1072, 'num_leaves': 93, 'max_depth': 11, 'learning_rate': 0.2772678124412466, 'feature_fraction': 0.6927489822398643, 'bagging_fraction': 0.7151944552299244, 'bagging_freq': 3, 'min_child_samples': 46, 'reg_alpha': 2.208836608762023, 'reg_lambda': 7.703132753535461e-07}. Best is trial 39 with value: 15.086310672033571.
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# Best trial: 39. Best value: 15.0863: 100%|███████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.28it/s]
# /Users/mohsen/Desktop/nyc_duration_prediction/.venv/lib/python3.11/site-packages/lightgbm/sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# 2026/08/02 15:22:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run lgb_trial_49 at: http://127.0.0.1:5000/#/experiments/2/runs/d20e764304f34d8ead015c47c9822c1c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# [I 2026-08-02 15:22:16,960] Trial 49 finished with value: 15.100225949423145 and parameters: {'n_estimators': 784, 'num_leaves': 119, 'max_depth': 11, 'learning_rate': 0.010562280287912068, 'feature_fraction': 0.7136094096989708, 'bagging_fraction': 0.6889865789343828, 'bagging_freq': 4, 'min_child_samples': 36, 'reg_alpha': 2.020569932184842e-07, 'reg_lambda': 3.2685766938510875e-08}. Best is trial 39 with value: 15.086310672033571.
#
# ============================================================
# بهترین RMSE: 15.0863
#   n_estimators: 1575
#   num_leaves: 97
#   max_depth: 12
#   learning_rate: 0.17075199793100013
#   feature_fraction: 0.8380437967774259
#   bagging_fraction: 0.6715444343299501
#   bagging_freq: 6
#   min_child_samples: 36
#   reg_alpha: 0.16046816541103484
#   reg_lambda: 4.5718392090250646e-05
# ============================================================
# 2026/08/02 15:22:21 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# ✅ مدل نهایی لاگ شد (همراه با Artifactهای پیش‌پردازش).
# 🏃 View run lightgbm_optuna_tuning_version_5 at: http://127.0.0.1:5000/#/experiments/2/runs/85b2336ec3534e37b880d2a0111504b6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
import mlflow
from mlflow.tracking import MlflowClient
from mlflow.models import infer_signature

mlflow.set_tracking_uri("http://127.0.0.1:5000")
client = MlflowClient()

model_name = "NYC_Taxi_Duration_LightGBM_version_5"

# ========================
# پیدا کردن بهترین Run
# ========================
runs = client.search_runs(
    experiment_ids=["2"],   # شماره Experiment خودت را بگذار
    filter_string="tags.mlflow.runName = 'lightgbm_optuna_tuning_version_5'",
    order_by=["metrics.best_rmse ASC"],
    max_results=1
)

if not runs:
    print("Run پیدا نشد!")
else:
    best_run = runs[0]
    run_id = best_run.info.run_id
    best_rmse = best_run.data.metrics.get("best_rmse")

    print(f"بهترین Run پیدا شد: {run_id}")
    print(f"بهترین RMSE: {best_rmse}")

    # ========================
    # ثبت مدل در Registry
    # ========================
    model_version = mlflow.register_model(
        model_uri=f"runs:/{run_id}/model",
        name=model_name
    )

    print(f"مدل ثبت شد → Version: {model_version.version}")

    # ========================
    # اضافه کردن توضیحات (Description)
    # ========================
    description = f"""
LightGBM model trained with Optuna hyperparameter tuning.

- Training Period: January & February 2026
- Best Validation RMSE: {round(best_rmse, 4)}
- Number of Optuna Trials: 50
- Feature Engineering: Target Encoding on PU_DO
- Final Features: trip_distance, pickup_dayofweek, PU_DO_encoded, hour_category (One-Hot)
- n_jobs: 2
"""

    client.update_model_version(
        name=model_name,
        version=model_version.version,
        description=description.strip()
    )

    # ========================
    # اضافه کردن تگ‌ها (Tags)
    # ========================
    tags = {
        "project": "NYC_Taxi_Duration",
        "team": "Data Science",
        "model_type": "LightGBM",
        "tuning_method": "Optuna",
        "training_period": "Jan-Feb 2026",
        "best_rmse": str(round(best_rmse, 4)),
        "number_of_trials": "50",
        "feature_engineering": "Target Encoding",
        "created_by": "Mohsen"
    }

    for key, value in tags.items():
        client.set_model_version_tag(
            name=model_name,
            version=model_version.version,
            key=key,
            value=value
        )

    # ========================
    # تنظیم Alias به عنوان Champion
    # ========================
    client.set_registered_model_alias(
        name=model_name,
        alias="champion",
        version=model_version.version
    )

    print(f"✅ مدل به عنوان @champion تنظیم شد (Version {model_version.version})")
    print("Description و Tags با موفقیت اضافه شدند.")
# Out:
# Successfully registered model 'NYC_Taxi_Duration_LightGBM_version_5'.
# 2026/08/02 15:24:11 WARNING mlflow.tracking._model_registry.fluent: Run with id 85b2336ec3534e37b880d2a0111504b6 has no artifacts at artifact path 'model', registering model based on models:/m-17b5b0323cf6490e8b4f0a0cd8ba7e04 instead
# 2026/08/02 15:24:11 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: NYC_Taxi_Duration_LightGBM_version_5, version 1
# بهترین Run پیدا شد: 85b2336ec3534e37b880d2a0111504b6
# بهترین RMSE: 15.086310672033571
# مدل ثبت شد → Version: 1
# Created version '1' of model 'NYC_Taxi_Duration_LightGBM_version_5'.
# ✅ مدل به عنوان @champion تنظیم شد (Version 1)
# Description و Tags با موفقیت اضافه شدند.

# %%
import mlflow
import pandas as pd
import joblib

# ========================
# تنظیمات
# ========================
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# ========================
# 1. لود کردن مدل
# ========================
model = mlflow.sklearn.load_model("models:/NYC_Taxi_Duration_LightGBM_version_4@champion")
print("✅ مدل لود شد.")

# ========================
# 2. لود کردن پیش‌پردازش‌ها
# ========================
target_encoder = joblib.load("target_encoder.pkl")
dv = joblib.load("dict_vectorizer.pkl")
print("✅ پیش‌پردازش‌ها لود شدند.")

# ========================
# 3. ایجاد داده نمونه
# ========================
new_data = pd.DataFrame({
    'trip_distance':     [1.8, 4.5, 9.2, 2.1, 15.0],
    'pickup_dayofweek':  [2, 5, 0, 6, 3],
    'PU_DO':             ['237_236', '142_43', '88_144', '237_236', '161_100'],
    'hour_category':     ['morning_peak', 'midday', 'evening_peak', 'late_night', 'morning_peak']
})

# ========================
# 4. پیش‌پردازش به روش درست (مهم)
# ========================

# Target Encoding
new_data['PU_DO_encoded'] = target_encoder.transform(new_data[['PU_DO']])

# تبدیل hour_category به One-Hot
cat_dicts = new_data[['hour_category']].to_dict(orient='records')
X_cat = dv.transform(cat_dicts)
X_cat_df = pd.DataFrame(X_cat.toarray(), columns=dv.get_feature_names_out())

# فقط فیچرهای عددی مورد نیاز (بدون ستون تکراری)
numerical_features = ['trip_distance', 'pickup_dayofweek', 'PU_DO_encoded']

# ساخت نهایی
X_new = pd.concat([
    new_data[numerical_features].reset_index(drop=True),
    X_cat_df
], axis=1)

print(f"\nتعداد فیچر X_new: {X_new.shape[1]}")
print("ستون‌های X_new:")
print(X_new.columns.tolist())

# ========================
# 5. هم‌تراز کردن ستون‌ها با X_train (خیلی مهم)
# ========================
# این خط باعث می‌شود X_new دقیقاً همان ستون‌ها و ترتیب X_train را داشته باشد
X_new = X_new[X_train.columns]

print(f"\nبعد از هم‌ترازسازی:")
print(f"تعداد فیچر X_new: {X_new.shape[1]}")
print("ستون‌ها:", X_new.columns.tolist())

# ========================
# 6. پیش‌بینی
# ========================
predictions = model.predict(X_new)

new_data['predicted_duration'] = predictions.round(2)

print("\n" + "="*65)
print("نتایج پیش‌بینی:")
print(new_data[['trip_distance', 'PU_DO', 'hour_category', 'predicted_duration']])
print("="*65)
# Out:
# Downloading artifacts: 100%|██████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 119.31it/s]
# ✅ مدل لود شد.
# ✅ پیش‌پردازش‌ها لود شدند.
#
# تعداد فیچر X_new: 11
# ستون‌های X_new:
# ['trip_distance', 'pickup_dayofweek', 'PU_DO_encoded', 'PU_DO_encoded', 'hour_category=evening_peak', 'hour_category=late_night', 'hour_category=midday', 'hour_category=morning_peak', 'hour_category=night', 'pickup_dayofweek', 'trip_distance']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 62
#      58 # ========================
#      59 # 5. هم‌تراز کردن ستون‌ها با X_train (خیلی مهم)
#      60 # ========================
#      61 # این خط باعث می‌شود X_new دقیقاً همان ستون‌ها و ترتیب X_train را داشته باشد
# ---> 62 X_new = X_new[X_train.columns]
#      63
#      64 print(f"\nبعد از هم‌ترازسازی:")
#      65 print(f"تعداد فیچر X_new: {X_new.shape[1]}")
#
# AttributeError: 'csr_matrix' object has no attribute 'columns'

# %%
print("\nتعداد فیچر X_train:", X_train.shape[1])
print("تعداد فیچر X_new   :", X_new.shape[1])
print("ستون‌ها یکسان هستند؟", X_train.columns.tolist() == X_new.columns.tolist())
# Out:
# تعداد فیچر X_train: 8
# تعداد فیچر X_new   : 11
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 3
#       1 print("\nتعداد فیچر X_train:", X_train.shape[1])
#       2 print("تعداد فیچر X_new   :", X_new.shape[1])
# ----> 3 print("ستون‌ها یکسان هستند؟", X_train.columns.tolist() == X_new.columns.tolist())
#
# AttributeError: 'csr_matrix' object has no attribute 'columns'
